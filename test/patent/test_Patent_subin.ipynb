# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from IPython.display import Image
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime

# %%
# webdriver를 이용해 kipris 접속
driver_path = r'C:\DevRoot\download\chromedriver.exe'
driver = webdriver.Chrome(driver_path)
driver.get("http://kpat.kipris.or.kr/kpat/searchLogina.do?next=MainSearch#page1")

# %%
# 기간을 검색어로 입력
today = datetime.today().strftime("%Y%m%d")
decade = str(int(today) - int('00100000'))

driver.find_element_by_css_selector('.keyword').send_keys(f'GD=[{decade}~{today}]')
driver.find_element_by_css_selector('.input_btn img').click()

# %%
html = driver.page_source
dom = BeautifulSoup(html, 'html.parser')
# dom

# %%
patent_list = dom.select('.search_section article')

result = [
        {
            '제목': patent.select_one('.stitle > a:nth-of-type(2)').text.strip(),
            '내용': patent.select_one('.search_txt').text.strip()
        }
        for patent in patent_list
]

result
# Out:
# [{'제목': '확장 가능한 지압구(EXTENDABLE ACUPRESSURE DEVICE)',
#   '내용': '본 고안은 지압구에 관한 것으로, 보다 상세하게는 다수의 지압구를 상호 인접되게 결합함으로써 지압 가능 구역을 확장시킬 수 있는 지압구에 관한 것이다. 본 고안에 확장 가능한 지압구는, 측면에 둘레를 따라 다수의 면을 포함하도록 다각 블럭 형태로 구성된 메인몸체와; 상기 메인몸체의 상면에 돌출 배치된 지압봉과; 인접 배치되는 다른 지압구와 자력에 의해 결합될 수 있도록 상기 메인몸체의 측면에 구비되는 결합용 자석을 포함한다.'},
#  {'제목': '그물망 벤치(net type bench)',
#   '내용': '본 고안은 프레임부와, 전방 지지대 및 후방 지지대와, 네트부 및 연결부를 포함하여 구성되며, 상기 네트부는 전방측에 비해 후방측이 높게 위치되도록 설치되면서 그물망으로 이루어지고, 사용자는 상기 프레임부에 걸터 앉을 수 있도록 구성된 그물망 벤치를 제공한다. 즉, 본 고안의 그물망 벤치는 단순히 앉아서 쉬는 형태의 벤치가 아니라 눕거나 기댄 상태로 휴식을 취할 수 있는 형태의 벤치이며, 특히 그물망 구조의 네트부를 제공함으로써 안락감을 더욱 향상시키면서도 안정적인 설치 상태가 유지될 수 있도록 한 것이다.'},
#  {'제목': '추진장약 분리장치(SEPARATION APPARATUS FOR PROPELLING CHARGE)',
#   '내용': '개시된 내용은 메쉬망에 올려진 추진장약이 좌우이동 프레임의 연속적인 좌우방향 이동과, 전후이동 프레임의 연속적인 전후방향 이동 그리고 호퍼부재에 구비되는 진동모터의 진동에 의해 상대적으로 입자가 큰 추진제와 입자가 작은 점화제로 분리되되, 추진제는 메쉬망에 걸러져 회동 프레임의 회동시 제 1 배출구를 통해 배출되고 점화제는 메쉬망을 통과해 제 2 배출구와 연결된 진공흡입식 포집기에 배출됨에 따라 신속하고 용이한 분리작업이 가능할 뿐만 아니라, 구성부재의 재료들이 전도성 기능을 갖는 스테인리스 또는 알루미늄 재질로 이루어지고, 실린더기구 및 모터들이 전기사용을 배제한 공압식으로 작동됨에 따라 안전사고가 방지될 수 있도록 한 추진장약 분리장치에 관한 것이다. 개시된 내용에 따른 추진장약 분리장치는 지면에 안착 지지되고 일측에 수직방향으로 지주대가 구비된 베이스 프레임과, 상기 지주대 상단에 그 하부 일측이 회동 가능하게 힌지 고정되고 일측 가장자리에 제 1 실린더기구가 작동 가능하게 설치되며 상부면 양측에 한 쌍의 제 1 이동레일이 좌우방향으로 평행하게 구비되는 회동 프레임과, 일측은 상기 베이스 프레임에 설치되고 타측은 상기 회동 프레임 하부 타측에 설치되며 작동여부에 따라 상기 회동 프레임이 회동되게 하는 제 2 실린더기구와, 상기 회동 프레임 상에 위치되되 그 하부면에 상기 제 1 이동레일과 결합되는 한 쌍의 제 1 가이드가 구비되며 그 일측이 상기 제 1 실린더기구에 연결되어 상기 제 1 실린더기구의 작동여부에 따라 좌우방향으로 연속이동되고, 일측 가장자리에 제 3 실린더기구가 작동 가능하게 설치되며 상부면 양측에 한 쌍의 제 2 이동레일이 전후방향으로 평행하게 구비되는 좌우이동 프레임과, 상기 좌우이동 프레임 상에 위치되되 그 하부면에 상기 제 2 이동레일과 결합되는 한 쌍의 제 2 가이드가 구비되며 그 일측이 상기 제 3 실린더기구에 연결되어 상기 제 3 실린더기구의 작동여부에 따라 전후방향으로 연속이동되는 전후이동 프레임과, 호퍼형상으로 형성되어 상기 전후이동 프레임 내측에 구비되되 내부에는  ....'},
#  {'제목': '방향전환연결이 가능한 직관형 LED 램프(LED LAMP OF STRAIGHT PIPE TYPE)',
#   '내용': '본 고안은 서로 마주하는 복수의 LED 램프를 간편하게 접속단자끼리 전기적으로 확장 연결할 수 있는 것은 물론, 램프와 램프가 소정의 각도로 방향전환연결이 가능한 LED 램프에 관한 고안이다. 본 고안은 내부에 LED 램프 모듈이 삽입되는 LED 램프용 커버; 상기 LED 램프용 커버의 양측단에 끼움 결합되며 끼움구가 관통 형성되는 지지대; 및 상기 지지대의 끼움구에 끼워져 상기 일측 LED 램프 모듈과 접속되는 제1접속부와, 일측은 상기 제1접속부와 접속되고 타측은 타측 LED 램프 모듈과 접속되는 제2접속부와, 상기 제1접속부와 제2접속부를 연결하면서 소정의 각도로 회전 가능하도록 구비되는 힌지부를 포함하는 방향전환연결부;로 구성되는 것을 특징으로 한다. 본 고안은 복수의 LED 램프 간에 간편하게 전기적으로 연결 가능하며, 소정의 각도로 방향전환이 되어 연결 가능한 장점이 있다.'},
#  {'제목': '문틈 안전 커버(Safety cover of chink in the door)',
#   '내용': '본 고안은 문틀과 도어가 여닫이식으로 구성될 때 형성되는 문틈을 보호 커버로 덮음으로써 손 끼임이 발생하지 않도록 하는 동시에, 보호 커버를 구성하는 제1 커버와 제2 커버를 연결하는 제2 힌지가 곡선으로 형성되어 도어가 열리거나 닫힐 때 제2 힌지를 기준으로 제1 커버와 제2 커버가 보다 용이하기 접혀지거나 펼쳐지도록 하는 문틈 안전 커버에 관한 것이다. 이를 위하여, 본 고안은 문틀과 도어 사이에 형성된 문틈을 덮어 가리는 문틈 안전 커버에 있어서, 일단부가 상기 문틀에 결합되며, 타단부가 상기 도어에 결합되어 상기 문틈을 가리는 보호 커버와, 상기 보호 커버의 타단부와 결합되는 도어 결합부 커버를 포함하며, 상기 보호 커버는 상기 문틀에 결합되되, ㄱ자 형상으로 형성된 문틀 결합부와, 상기 도어에 결합되는 도어 결합부와, 일단과 타단이 상기 문틀 결합부과 상기 도어 결합부에 각각 연결되어 상기 문틈을 덮어 가리는 커버부를 포함한다.'},
#  {'제목': '양면 사용 롤블라인드(Roll blinds)',
#   '내용': '본 고안은 양면 사용 롤블라인드에 관한 것으로서, 사용자가 필요에 따라 양면스크린의 앞뒷면을 전환 사용하여 롤블라인드의 기능성을 향상시킬 수 있도록 함을 목적으로 한 것이다. 즉, 본 고안은 롤블라인드에 있어서, 일측 외면에 장착부를 형성하고 내부에 수용공간을 갖는 롤하우징과 상기 롤하우징에 수납되어 양단이 회전축지되는 전환권취롤, 상기 전환권취롤에 일단이 구속되며 양측에 각기 다른 기능면을 갖는 양면스크린, 상기 전환권취롤의 일단에 축결되어 사용자의 권취조작줄 조작에 따라 전환권취롤을 권취 및 권해 회전시키는 롤조작부로 구성한 것을 특징으로 하는 것이다. 따라서, 본 고안은 사용자가 필요에 따라 양면스크린의 앞뒷면을 전환 사용하여 롤블라이드의 장식성과 기능성이 향상되는 효과를 갖는 것이다.'},
#  {'제목': '캔들 워머 조명(CANDLE WARMER LIGHTING)',
#   '내용': '캔들 워머 조명이 개시된다. 캔들 워머 조명은, 상측에 캔들이 설치되는 안착부가 형성되는 베이스부와, 일단은 베이스부의 측면에 연결되고 타단은 베이스부의 상부로 연장되는 지지부와, 지지부의 타단에 연결되어 상기 캔들의 상부를 덮는 캡 조립체를 포함한다. 여기서, 캡 조립체는, 지지부의 타단에 연결되는 캡부와, 캡부에 일측이 연결되고 타측은 캔들의 상부 둘레를 덮으며 외부 둘레는 화염 조명이 노출되는 표시부가 형성되는 외부 갓과, 외부 갓의 내부에 고정되며 화염 조명이 외부갓으로 투과되는 내부 갓을 포함할 수 있다.'},
#  {'제목': '창틀 고정용 지지 구조체(BRACKET FOR WINDOW FRAME FIXATION)',
#   '내용': '본 고안에 따른 창틀 고정용 지지 구조체는 복수의 구성요소가 일체로 사출 성형된다. 이러한 창틀 고정용 지지 구조체는 복수의 구성요소가 일체로 사출 성형됨으로써, 구성요소들 간의 분리나 균열을 방지할 수 있을 뿐만 아니라 콘크리트 벽체의 외측에 가까운 수직보강부 및 제 2 창틀지지부가 내외부 온도차에 따른 수분과의 반응성이 낮은 재질로 이루어짐으로써, 콘크리트 벽체 및 창틀의 결로를 방지할 수 있다. 또한, 본 고안에 따른 창틀 고정용 지지 구조체는 일부 구성요소가 수분과의 반응성이 낮은 재질로 이루어져 콘크리트 벽체 및 창틀의 결로를 방지함으로써, 곰팡이 등의 유해균 증식을 억제할 수 있다.'},
#  {'제목': '이동식 미니 흡연부스(MOVABLE MINI SMOKING BOOTH)',
#   '내용': '본 고안은 이동식 미니흡연부스에 관한 것으로서, 소형의 구조를 이루는 흡연부스의 이동이 가능하도록 하여 흡연부스의 사용 편의성을 향상시키도록 하기 위한 것이다. 이를 실현하기 위한 본 고안은, 이용자의 출입이 가능하도록 일 측에 출입구(11)가 구비된 부스본체(10)와; 상기 부스본체(10)의 이동이 가능하도록 하부에 구성되는 이동바퀴(20)와; 상기 부스본체(10)의 상부에 연결되어 창문(100)을 통한 외기와 연통이 이루어지는 통풍관(30)과; 상기 통풍관(30)에 구성되어 담배연기를 외부로 강제 송풍시키는 환풍팬(40)을 포함하는 구성을 이루는 것을 특징으로 한다.'},
#  {'제목': '착즙 드럼 및 착즙기(JUICE SQUEEZING DRUM AND JUICER)',
#   '내용': '본 고안은 착즙 드럼 및 착즙기에 관한 것이다. 본 고안의 실시예에 의한 착즙 드럼은 내부에서 회전하는 스크류에 의해 착즙 대상의 즙과 찌꺼기를 분리하는 착즙 드럼으로써, 상기 스크류를 수용할 수 있도록 상부가 개방된 중공 원통으로 형성되고 내주면을 따라 양측면과 상면과 하면을 갖는 관통구멍으로 형성된 복수 개의 슬릿이 형성되는 내측 모듈, 및 상기 내측 모듈을 상부측에서 착탈이 가능하도록 상부가 개방되고, 내주면에 돌출면과 상면과 하면을 포함하는 리브가 반경 방향 내측으로 돌출되어 형성되는 외측 모듈을 포함하고, 상기 외측 모듈이 상기 내측 모듈을 둘러싸 결합될 때 상기 외측 모듈의 상기 리브가 상기 내측 모듈의 상기 슬릿에 삽입되어 상기 내측 모듈의 슬릿 측면과 상기 외측 모듈의 리브 측면사이에서 상기 스크류에 의해 착즙된 즙이 배출되는 소정의 고정된 틈이 상하 방향으로 길게 형성되고, 상기 고정된 틈은 스크류 날과 교차하는 방향으로 형성될 수 있다.'},
#  {'제목': '밀폐용 내부 포켓이 구비된 완충 포장 박스(A shock-absorbing package box with an inner sealing pocket)',
#   '내용': '본 고안은 밀폐용 내부 포켓이 구비된 완충 포장 박스에 관한 것으로서, 더욱 상세하게는 복수의 공기셀로 이루어지는 완충용 포장재를 박스 형태로 융착 형성하여, 상부에 덮개가 구비된 직육면체 형태의 완충 포장 박스로 형성하되, 이와 같은 완충용 포장재의 박스 형성 과정에서 상부가 개구된 주머니 형태의 내부 포켓의 양측면을 박스 내벽에 부분적으로 융착하여, 완충 포장 박스 내에, 물품을 수용하기 위한 내부 포켓을 일체로 구비함으로써, 물품 포장시, 내부 포켓에 물품을 수용하고 끈이나 와이어, 케이블타이 또는 지퍼락 등의 밀봉수단을 통해 내부 포켓의 개방된 상부를 완전히 밀봉한 후, 완충 포장 박스에 구비된 덮개를 덮고 테이핑하여 마감함으로써, 내부에 수용된 물품을 긴밀하게 밀폐 포장할 수 있는 동시에 안전하게 보호할 수 있어, 외부로 새기 쉬운 액상의 물품이나, 수분을 포함하는 물품 또는 얼음 등을 효과적으로 밀폐하여 포장할 수 있는 밀폐용 내부 포켓이 구비된 완충 포장 박스에 관한 것이다.'},
#  {'제목': '살균기의 완충형 스위치 어셈블리(Shock-absorbing type switch assembly of sterilizer)',
#   '내용': '살균기의 완충형 스위치 어셈블리에 관한 것으로, 살균기의 본체에 삽입되어 슬라이딩 이동되는 슬라이드핀, 버튼이 돌출된 전면이 본체의 입구를 향하도록 본체의 내부에 설치되는 푸시스위치, 탄성을 갖도록 횡방향으로 절곡되고 슬라이드핀의 후단이 접촉된 덮개판 및 버튼의 외주면을 감싸고 덮개판의 전후진에 의해 길이가 가변되는 보호패킹을 포함하여, 도어가 닫히면서 슬라이드핀을 후진 이동시키고 후진 이동하는 슬라이드핀은 덮개판을 누르고, 눌린 덮개판은 푸시스위치의 버튼을 누르는 과정에서 슬라이드핀의 후진력을 덮개판의 탄성과 보호패킹의 탄성에 의해 감소시켜 푸시스위치의 파손을 방지할 수 있고 외부의 이물질이 버튼으로 유입되는 것을 방지할 수 있다.'},
#  {'제목': '휴대용 스피커 탈부착형 스테레오 사운드 북(Sound book)',
#   '내용': '본 고안은 휴대용 스피커 탈부착형 스테레오 사운드 북에 관한 것으로서, 보다 상세하게는 사운드 북 몸체의 상면 또는 하면에 탈부착 수단에 의해 대략 얼굴 형상의 듀얼 스피커가 포함된 사운드 몸체를 탈부착가능하도록 하여 비사용시에는 견고한 부착과 소형화로 인해 휴대가 간편하고, 사용시에 듀얼 스피커 형성에 의해 사운드 북에 인쇄된 문자 또는 이미지와 관련된 음향 컨텐츠를 다양한 얼굴 표정과 함께 입체 사운드의 좋은 음질로 제공받을 수 있는 휴대용 스피커 탈부착형 스테레오 사운드 북에 관한 것이다.'},
#  {'제목': '카드 케이스 제작용 사출 금형(INJECTION MOLD FOR MAKING CARD CASE)',
#   '내용': '카드 케이스 제작용 사출 금형이 개시된다. 본 고안의 일 실시예에 따른 사출 금형은 상부 금형 및 하부 금형을 포함하되, 상기 하부 금형은, 소정의 높이를 가지는 내부코어 및 상기 내부코어의 너비 방향으로 확정되고 하부에 빈 공간이 형성된 복수의 변형 밀핀을 포함하고, 상기 상부 금형은, 상기 하부 금형과 결합될 때 상기 변형 밀핀과 마주보는 위치에 상기 변형 밀핀을 향하는 방향으로 돌출된 돌출부를 포함한다.'},
#  {'제목': '슬라이딩 휴대전화 케이스(SLIDING TYPE PHONE CASE)',
#   '내용': '본 고안은 슬라이딩 휴대전화 케이스에 관한 것으로서, 휴대전화의 후면이 위치하며 내부에 금속재가 삽립된 본체부, 상기 휴대전화의 후면이 부착되도록 상기 본체부의 일면 상부에 결합된 판형상의 슬라이딩부 및 상기 본체부와 상기 슬라이딩부를 서로 밀착시키도록 상기 슬라이딩부의 내부에 삽입되는 자석을 포함하고, 상기 슬라이딩부는 상기 휴대전화의 하부를 밀어 올리는 경우, 상기 휴대전화가 상부방향으로 이동하여 상기 휴대전화의 카메라 모듈이 노출되도록 접혀지는 것을 특징으로 하는 슬라이딩 휴대전화 케이스에 관한 것이다.'},
#  {'제목': '탱크의 처리, 크리닝 장치(Tank treatment, cleaning equipment)',
#   '내용': '본 고안은 자력 또는 외력에 의하여 회전하는 회전체, 이에 감김 또는 풀림되어 승강하는 줄, 이의 줄에 거치되어 승강하는 기구, 이의 기구에 거치된 처리기, 이의 처리기에 처리제를 공급하는 공급라인, 상기 처리제를 가압하여 공급라인에 공급하는 콤프레셔 등이 구비된 탱크 내부의 처리 장치로서, 상기 줄에 걸리는 하중을 분산시키기 위하여 상기 회전체는 탱크에 형성된 홀에 거치되어 상기 줄이 통과되는 회전체a와 이에 연계되면서 상기 홀에 이격되게 거치되어 상기 회전체a를 통과한 줄이 감김 또는 풀림되는 회전체b의 2개 회전체로 구성되고, 상기 홀은 천공기, 불꽃, 드릴, 홀드릴 등에 의하여 형성되고, 상기 기구의 하부에 스프링, 스펀지; 상부에 스프링, 스펀지; 내부에 스프링; 측면에 스프링, 스펀지, 로라 등이 구비되는 것을 특징으로 한다.'},
#  {'제목': '기어의 원리를 이용한 높이조절이 가능한 창문 고정 장치(FIXING APPARATUS FOR WINDOW)',
#   '내용': '본 고안은 기어의 원리를 이용한 높이조절이 가능한 창문 고정 장치에 관한 것으로서, 제1창문 프레임에 마련되는 창문 고리; 상기 창문 고리에 걸림유지 및 걸림해제되는 걸림쇠를 가지며, 상기 걸림쇠가 상기 창문 고리에 걸림유지되어 창문이 잠기는 제1위치와, 상기 창문 고리로부터 걸림해제되어 창문이 잠금해제되는 제2위치 사이를 이동하도록, 상기 제1창문 프레임과 함께 창문을 형성하는 제2창문 프레임에 회전가능하게 마련되는 레버; 상기 레버에 결합되어, 상기 레버를 회전시키는 제1피니언; 사각형 단면의 바아 형상을 가지며, 일측면에 상기 제1피니언과 맞물리는 제1랙이 형성되고, 타측면에 상기 제1랙과 동일 방향을 따라 제2랙이 형성되며, 상기 제1피니언을 회전시키는 승강 랙; 상기 승강 랙의 제2랙에 맞물려 회전하며, 상기 승강 랙을 승강시키는 제2피니언; 상기 제2피니언에 결합되어, 상기 레버의 걸림쇠가 상기 제1위치와 상기 제2위치 사이를 왕복 이동하도록 상기 제2피니언을 회전시키는 노브; 상기 승강 랙의 승강방향을 따라 상기 승강 랙에 관통 형성되어, 상기 걸림쇠의 제1위치와 상기 제2위치 사이의 회전 원호 길이에 대응하는 직선 길이를 가지며, 상기 승강 랙의 승강을 안내하는 가이드; 및 상기 가이드에 관통하며 상기 제2창문 프레임에 결합되어, 상기 가이드를 따라 승강하는 상기 승강 랙의 승강을 제한하는 스토퍼를 포함하는 것을 특징으로 한다.'},
#  {'제목': '밀폐구조 튜브형 화장품용기(AIRTIGHT STRUCTURE TUBE TYPE COSMETIC CONTAINER)',
#   '내용': '본 고안은 립글로스 화장용액등의 겔상의 화장품을 수용하는 튜브용기(8)에 있어서 상캡(9)을 열고 사용중에 화장용액의 수분증발 또는 알콜성분의 증발을 최소화시키기 위해서 관통형 토출관(4) 속에 실리콘재질의 실리콘마개(5)를 구비한 밀폐구조의 튜브형 화장품용기에 관한 것으로 , 상세하게는 립글로스가 수용되는 튜브용기(8)의 개구부(13)와 결합되는 관통형 토출관(4)을 개선하여 후로킹팁(2)과 결합되는 관통형 토출관(4) 속에 튜브용기(8) 속으로 공기를 차단하는 실리콘마개(5) 상면을 다수 분할로 절개한 토출구a(6)를 구비한 실리콘마개(5)를 결합하여 , 립글로스를 짜서 입술에 바를때 튜브용기(8)를 누르면 립글로스 내용물의 압력으로 실리콘마개(5)의 상면을 절개한 토출구a(6)가 열리면서 내용물이 토출되어 후로킹팁(2)의 토출구b(1)로 립글로스 화장용액이 토출되어 사용자가 입술에 화장을 편리하게 바를수 있으며 ; 튜브용기(8)를 누르지 않을때는 실리콘마개(5)의 절개한 토출구a(6)가 원상복귀되어 절개한 토출구a(6)가 열리지 않아 공기가 차단되어 튜브용기(8) 속으로 공기가 유입되지 않기 때문에 튜브용기(8) 속의 립글로스 화장용액의 수분증발이나 알콜성분의 증발을 차단함으로써 립글로스 화장용액의 변질을 방지하여 립글로스의 사용 기간을 연장할 수 있다 . 또한 사용하지 않고 보관시에 상캡(9)을 닫을때도 상캡(9) 나사(11) 하단 내주면으로 형성된 탄성부재를 이중사출로 성형시켜 탄성부재링(10)으로 구성하여 튜브용기(8)의 나사(12) 하단에 형성되는 밀폐턱(7)과 밀착되게 잠기면서 상캡(9) 속의 공기를 밀폐시키므로서 후로킹팁(2) 토출구b(1)의 화장용액 잔량이 마르지않고 토출관(4) 속으로의 공기 유입을 차단하도록 고안한 것이다 .'},
#  {'제목': '기울림 방지 보호 케이스(ANTI-TILT PROTECTIVE CASE)',
#   '내용': '본 고안은 고정 부재의 기술분야에 관한 것으로서, 특히는 기울림 방지 보호 케이스에 관한 것이다. 통상적으로 파손이 용이한 용기(예를 들면 도자기 용기, 유리 용기) 외주에 커버 설치되고, 본체를 포함하고, 상기 본체에 상기 용기를 수용 가능한 캐비티가 오목 설치되어 있으며, 상기 본체의 최상부에 상기 용기가 안착되도록 제공하는 개구가 개설되어 있고, 상기 캐비티와 상기 개구는 연통되며, 상기 본체의 최저부에는 지지면에 흡착 가능하고 상기 용기의 기울림을 방지할 수 있는 흡반이 외부로 연신되게 설치되어 있다. 선행기술과 비교하면, 용기 외측에 기울림 방지 및 파손 방지 보호 케이스를 커버 설치하는 것을 통해, 상기 보호 케이스의 내벽은 상기 용기의 외벽에 긴밀하게 접착되어, 상기 파손이 용이한 용기를 상기 보호 케이스 내에 초보적으로 고정시킬 수 있고, 이 밖에, 최저부에 설치된 흡반을 통해, 보호 케이스와 용기를 함께 지지면에 고정시켜, 이로써 사람이 부주의로 상기 보호 케이스에 부딪혀도 상기 보호 케이스 내의 용기를 뒤엎을 수 없게 되어, 사람들의 생활의 질을 대폭 개선하였다.'},
#  {'제목': '배관 구조(PIPE STRUCTURE)',
#   '내용': '개시된 내용은 준비작동식 밸브, 압력게이지, 압력해제밸브를 연결할 수 있는 하나의 배관 구조에 관한 것이다. 개선된 배관 구조는 내부에 제1챔버 및 제1챔버와 연결되는 제2챔버가 형성된 메인파이프, 제1챔버가 위치하는 메인파이프 일단에 형성되는 제1결합부, 메인파이프의 길이방향 측면에서 제1챔버와 통하도록 형성되는 제2결합부, 메인파이프의 길이방향 측면에서 제1챔버와 통하도록 형성되는 제3결합부, 제2챔버가 위치하는 메인파이프의 타단에 형성되는 제4결합부 및 메인파이프의 내부에 결합되어 유체가 제2챔버에서 제1챔버 방향으로만 흐르게 하는 체크밸브를 포함할 수 있다.'},
#  {'제목': '텀블러(TUMBLER)',
#   '내용': '본 고안은 텀블러에 관한 것으로, 충진물의 양에 따라 크기를 용이하게 가변할 수 있고, 내부 세척이 용이하며, 종류가 다른 충진물을 섞이지 않도록 구획하여 충진할 수 있도록 함을 목적으로 한다. 본 고안에 따른 텀블러는, 서로 일정간격 이격되는 제1,2뚜껑부, 상기 제1,2뚜껑부의 사이에 배치되고, 내부에 충진공간이 형성된 제1,2용기부를 포함하고, 상기 제1,2뚜껑부 및 제1,2용기부에 각각 형성되고, 상기 제1뚜껑부와 제1용기부, 제1용기부와 제2용기부 및 제2용기부와 제2뚜껑부를 결합 또는 분리시키는 착탈부를 포함한다.'},
#  {'제목': '영어 단어 학습 카드(CARDS FOR STUDYING ENGLISH WORDS)',
#   '내용': '본 고안은 영어 단어 학습 카드에 관한 것으로, 해결하고자 하는 기술적 과제는 문장을 이루는 구성 단어의 뜻과 품사를 보다 쉽게 각각 인식할 수 있고, 영어 단어의 뜻과 품사를 인식한 단어로 문장을 쉽게 구성하고 이해할 수 있도록 하는데 있다. 이를 위해 본 고안은, 카드의 제1 면에 표기되는 영어 단어 및 상기 카드의 제2 면에 표기되며 상기 제1 면에 표기된 영어 단어의 한글 뜻을 나타내는 한글 단어를 포함하는 단어 의미 표기부; 상기 제1 면에 표기된 영어 단어의 품사 종류에 따라 상기 제1 면과 상기 제2 면 중 적어도 한 면에 상기 카드 별로 상이한 색상이 적용되어 표시되는 제1 품사 구별부; 및 상기 제1 면에 표기된 영어 단어의 품사 종류를 구별하기 위하여, 상기 제1 면 및 상기 제2 면 중 적어도 한 면에 표기되는 숫자 및 문자 중 적어도 하나를 포함하는 제2 품사 구별부를 포함하는 영어 단어 학습 카드를 개시한다.'},
#  {'제목': '내전근 및 괄약근 강화 운동기구(EXERCISE APPARATUS FOR ADDUCTOR AND SPHINCTER)',
#   '내용': '내전근 및 괄약근 강화 운동기구가 개시된다. 개시된 내전근 및 괄약근 강화 운동기구는 본체프레임; 상기 본체프레임 좌측 및 우측에 측방으로 직선왕복 이동가능하도록 설치되는 좌측 슬라이딩판 및 우측 슬라이딩판; 상기 좌측 슬라이딩판 및 우측 슬라이딩판의 각각의 상부에 회전가능하도록 설치되며, 상부에 각각 좌측 발안착부 및 우측 발안착부가 설치된 좌측발판 및 우측발판; 양단이 상기 본체프레임에 양측부에 고정되고, 상기 좌측발판과 상기 우측발판 각각에 권취되도록 설치되어, 상기 좌측 슬라이딩판 및 상기 우측 슬라이딩판의 직선운동에 대한 상기 좌측발판과 상기 우측발판의 회동각도를 제한시키는 회동각도규제 와이어; 상기 좌측 슬라이딩판 및 상기 우측 슬라이딩판과 상기 본체프레임의 일측을 각각 연결하도록 구성되어, 상기 좌측 슬라이딩판과 상기 우측 슬라이딩판의 이동시, 탄성력에 의한 운동부하를 제공하는 운동부하제공부;를 포함하는 것을 특징으로 한다.'},
#  {'제목': '길이 가변형 출입금지 표지판(LENGTH VARIABLE TYPE SIGN BOARD)',
#   '내용': '본 고안은 길이 가변형 출입금지 표지판에 관한 것으로서, 표시판의 설치가 이루어지는 출입구의 크기에 따라 표시판의 길이가 가변 조절가능하도록 하기 위한 것이다. 이를 실현하기 위한 본 고안은, 전면에 출입 통제를 위한 문자가 표기된 본체플레이트(10)와; 상기 본체플레이트(10)의 양측에 형성된 제1볼트공(11)과; 상기 본체플레이트(10)의 내부에 형성된 가이드홈(12)과; 상기 가이드홈(12)을 따라 슬라이딩 안내되어지는 가변플레이트(20)와; 상기 가변플레이트(20)의 일측에 형성된 제2볼트공(21);을 포함하는 구성을 이루는 것을 특징으로 한다.'},
#  {'제목': '휴대용 기초크림용기(Portable foundation cream container)',
#   '내용': '본 고안에 따른 휴대용 기초크림용기는 상부에 용기내부를 개폐할 수 있는 뚜껑이 구비되는 용기 본체와, 내부에 화장액이 수용되는 공간이 형성되고, 화장액이 수용되는 공간을 덮는 상판에는 화장액이 토출되는 다수의 토출구가 형성되며, 화장액 수용 공간의 하측에는 화장액을 지지하고 화장액을 밀어올려 토출구를 통해 토출시키기 위한 푸쉬판이 결합되고, 푸쉬판의 하부에 위치하는 바닥면의 일측에는 공기유입공이 형성되어 용기본체 내부에 결합되는 내부 용기와, 용기 본체의 내부에서 내부 용기 상측에 구비되어 내부용기의 토출구를 통해 토출되는 화장액을 묻혀 사용하기 위한 퍼프와, 용기 본체의 외측에서 공기 유입공으로 공기가 유입되도록 용기본체에 형성되는 공기 유입통로와, 용기 본체의 외부로부터 공기 유입통로를 통해 유입되는 공기가 내부 용기로 유입되는 것을 허용하고 반대방향으로의 공기 이동을 방지하기 위해 공기 유입통로의 일측에 구비되는 일방향 체크밸브와, 공기 유입통로가 형성되는 용기 본체의 외측에 구비되고, 중앙에는 통기공을 가지며 압축 및 복원가능하게 형성되어 압축시 공기 유입통로의 내부 공기를 체크밸브를 통해 내부 용기의 푸쉬판과 바닥면 사이의 공간으로 이동시키기 위한 형상체를 포함하여 이루어지는 것을 특징으로 한다.'},
#  {'제목': '록킹장치가 구비된 여닫이 창호(casement window with locking device)',
#   '내용': '본 고안은 록킹장치가 구비된 여닫이 창호가 개시되는 것으로, 창틀과 창문틀을 포함하는 여닫이 창호에 있어서, 창틀(100)에 구비되고 창문틀(200)의 일측부(210)와 연결되는 힌지체(110)와; 상기 힌지체(110)에 의해 창틀(100)과 일측부(210)가 연결되는 상기 창문틀(200)의 타측부(220)에 구비되고 창틀(100)의 상부와 하부에 대해 상기 창문틀(200)을 록킹 및 언록킹하는 록킹장치(300)를 포함하여 이루어진다. 본 고안은 여닫이 창호의 창틀에 설치되는 창문틀이 힌지체에 의해 힌지회전되어 개방된 후 닫혀질 때 창문틀에 구비된 록킹장치에 의해 창문틀의 상부와 하부가 창틀에 견고하게 고정되어 창문틀의 단속이 견고하게 이루어질 수 있으며, 창문틀의 록킹 및 언록킹이 회전레버의 회전동작에 의해 쉽고 용이하게 이루어짐에 따라 사용성 및 편의성을 크게 향상시킬 수 있고 간단한 구성에 의해 설치비용에 부담을 최소화할 수 있다.'},
#  {'제목': '스탠드형 농산물 건조대(Drying rack for farm produce of stand type)',
#   '내용': '본 고안은 공간 활용도가 매우 뛰어나고 다양한 종류의 농산물이 섞이지 않게 건조할 수 있으며, 농산물의 무게에 따라 균형 조절이 가능하여 넘어지는 것을 방지할 수 있는 스탠드형 농산물 건조대에 관한 것이다. 이러한 본 고안에 따른 스탠드형 농산물 건조대는 지면에 놓여지는 스탠드 받침부재와, 상기 스탠드 받침부재의 중심부에 수직하게 장착되는 지지봉과, 상기 지지봉의 직경 및 형상과 대응되는 중공이 형성되어 상기 지지봉이 관통 삽입되며 일측에 고정수단이 구비된 회전부재 및 소정의 면적을 가지며 건조물을 수용하기 위한 적재공간이 형성된 받침수단과, 상기 받침수단의 일측에 구비되어 상기 받침수단과 고정수단을 탈착 가능하게 연결하는 링크수단을 포함하는 건조물 받침부재를 포함하고, 상기 링크수단은, 상기 받침수단의 하측을 지지하며 탈착 가능하게 고정되는 지지플레이트와, 상기 지지플레이트의 일측에 돌출 구비되는 걸림프레임을 포함하고, 상기 고정수단은, 상기 회전부재에 고정되는 제1고정프레임과, 상기 제1고정프레임의 일측에 힌지결합되고 상기 걸림프레임이 내측에 삽입 및 고정되는 제2고정프레임을 포함하며, 상기 지지플레이트 상에 고정되는 상기 받침수단의 위치는 지면과 평행한 방향으로 가변 가능하고, 상기 제2고정프레임은 지면과 평행한 방향을 기준으로 90°범위 내에서 교차하는 방향으로 회전 가능하며, 상기 회전부재는 상기 지지봉의 높이 방향을 따라 다수 개가 순차적으로 장착되되, 개별적으로 회전 가능한 것을 특징으로 한다.'},
#  {'제목': '액체 배출용기(Container for discharging liquid)',
#   '내용': '본 고안의 일실시예에 따른 액체 배출용기는 내부에 액상의 내용물이 수용되는 공간이 형성되고, 폐쇄된 상부면의 중앙에는 내용물이 토출되는 토출구가 형성되며, 내부에는 내용물을 지지하고 내용물을 밀어올려 토출구를 통해 토출시키기 위한 푸쉬판이 결합되고, 하부에는 결합구가 형성되는 용기 몸체와, 용기 몸체의 하측에서 용기 몸체와 결합되어 상기 용기 몸체의 하부를 폐쇄하기 위한 폐쇄판 부재와, 상기 폐쇄판 부재의 중앙에 형성되어 공기의 상방향으로의 이동을 허용하고 공기의 하방향으로의 이동을 방지하는 일방향 체크밸브와, 용기 몸체의 결합구와 결합되기 위해 폐쇄판 부재의 상부에 둘레방향으로 형성되는 상부 체결구와, 폐쇄판 부재의 하부에 형성되는 하부 체결구로 이루어지는 중간 결합체와, 중간 결합체의 하부 체결구에 승하강 가능하게 결합되는 원통형상의 바닥 지지체와, 중간 결합체의 하부에 결합되고, 하단 중앙에는 통기공이 형성되어 중간 결합체의 하강에 의해 상기 바닥 지지체의 내부 바닥면에 접촉하여 통기공이 폐쇄되고 압축됨으로써 내부공기를 상기 체크밸브를 통해 상부로 이동시키기 위한 형상체를 포함하여 이루어지는 것을 특징으로 한다.'},
#  {'제목': '휴대용 케이블타이 고정구(Holder of cable tie)',
#   '내용': '본 고안은 휴대용 케이블타이 고정구에 관한 것이다. 본 고안에 따르면 작업자가 작업에 필요한 일정량의 케이블타이(C)를 용이하게 휴대할 수 있도록 하는 휴대용 케이블타이 고정구(1)에 있어서, 일정량의 케이블타이(C)를 결집하여 삽입하는 삽입부(100);와 상기 삽입부(100)에 삽입된 일정량의 케이블타이(C)를 고정하는 고정부(200); 및 상기 삽입부(100)의 일측에 위치하여 작업자의 벨트 또는 작업현장의 돌출된 형상으로 이루어진 물체에 걸거나 결속할 수 있도록 하는 관통된 홀(310)이 형성된 걸이부(300);로 구성되는 것을 특징으로 한다. 이때, 삽입부(100)는, 일정량의 케이블타이(C)가 삽입될 수 있도록 관통된 제 1관통홀(111)이 형성된 제 1하우징(110);과 상기 제 1하우징(110)과 맞대어 결합되고 제 1관통홀(111)로부터 삽입되는 일정량의 케이블타이(C)가 제 1관통홀(111)을 지나 길이방향으로 일정깊이 삽입이 유지될 수 있도록 관통된 제 2관통홀(121)이 형성된 제 2하우징(120);으로 구성되되, 제 1하우징(110)과 제 2하우징(120)에 각각 형성된 제 1관통홀(111)과 제 2관통홀(121)이 동일한 축 선상에 위치하여 결합되고 제 1하우징(110)과 제 2하우징(120) 사이에는 고정부(200)가 정해진 범위 내에서 자유롭게 움직일 수 있도록 케이블타이 고정부재 이동구간 홈(130);이 생성되도록 형성되고 제 1하우징(110)과 제 2하우징(120)이 결합된 내부 일측에는 고정부(200)와 결합되는 힌지 축(140);이 형성되도록 구성되며 제 1하우징(110)의 하면 외주연면 일측에는 고정부(200)를 고정하기 위한 돌출된 걸림턱(150);을 더 포함하여 이루어지고, 고정부(200)는, 일정량의 케이블타이(C)가 삽입부(100)로부터 작업자에 의한 의도적인 추출이외에 이탈되지 않도록 케이블타이(C)와 직접적으로 접촉되어 고정하는 케이블타이 고정부재(210);와 상기 케이블타이 고정부재(210)의 끝단부가 삽입부(100) 내에 형성된 힌지 축(140)과 결합 ....'},
#  {'제목': '전자 장치용 부착 시스템(ATTACHMENT SYSTEM FOR AN ELECTRONIC DEVICE)',
#   '내용': '본 개시의 실시예들은 소비자 제품의 부착 시스템을 위한 제거가능한 모듈 및 하우징을 제공한다. 제거가능한 모듈은 실질적으로 평면인 상단면을 가진 제1 부분 및 실질적으로 비평면인 바닥면을 포함하는 제2 부분을 포함하는 로킹 메커니즘을 포함한다. 제1 부분과 제2 부분은 함께 결합된다. 로킹 메커니즘은 또한 제1 부분과 제2 부분 사이에 결합된 제1 스프링 메커니즘을 포함한다. 제1 스프링 메커니즘은 제1 부분이 제2 부분으로부터 멀어지게 편향되게 한다. 로킹 메커니즘은 또한 제2 스프링 메커니즘을 포함한다. 제2 스프링 메커니즘은 제1 부분의 실질적으로 평면인 상단면이 제거가능한 모듈에 대하여 실질적으로 같은 높이로 편향되게 하고 또한 제2 부분의 실질적으로 비평면인 바닥면이 제거가능한 모듈에 대하여 돌출하게 편향되게 한다.'}]
