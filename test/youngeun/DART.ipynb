# %%
import OpenDartReader

# %%
api_key = '7e4400d321b22388767c3eded0823102081c97d9'

dart = OpenDartReader(api_key)

# %%
dart.finstate_all('005930', 2018)
# Out:
#            rcept_no reprt_code bsns_year corp_code sj_div  sj_nm  \
# 0    20190401004781      11011      2018  00126380     BS  재무상태표
# 1    20190401004781      11011      2018  00126380     BS  재무상태표
# 2    20190401004781      11011      2018  00126380     BS  재무상태표
# 3    20190401004781      11011      2018  00126380     BS  재무상태표
# 4    20190401004781      11011      2018  00126380     BS  재무상태표
# ..              ...        ...       ...       ...    ...    ...
# 213  20190401004781      11011      2018  00126380    SCE  자본변동표
# 214  20190401004781      11011      2018  00126380    SCE  자본변동표
# 215  20190401004781      11011      2018  00126380    SCE  자본변동표
# 216  20190401004781      11011      2018  00126380    SCE  자본변동표
# 217  20190401004781      11011      2018  00126380    SCE  자본변동표
#
#                                             account_id   account_nm  \
# 0                                   ifrs_CurrentAssets         유동자산
# 1                          ifrs_CashAndCashEquivalents     현금및현금성자산
# 2    dart_ShortTermDepositsNotClassifiedAsCashEquiv...       단기금융상품
# 3                                         -표준계정코드 미사용-   단기매도가능금융자산
# 4                                         -표준계정코드 미사용-  단기상각후원가금융자산
# ..                                                 ...          ...
# 213                                        ifrs_Equity         기말자본
# 214                                        ifrs_Equity         기말자본
# 215                                        ifrs_Equity         기말자본
# 216                                        ifrs_Equity         기말자본
# 217                                        ifrs_Equity         기말자본
#
#                             account_detail thstrm_nm    thstrm_amount  \
# 0                                        -    제 50 기  174697424000000
# 1                                        -    제 50 기   30340505000000
# 2                                        -    제 50 기   65893797000000
# 3                                        -    제 50 기
# 4                                        -    제 50 기    2703693000000
# ..                                     ...       ...              ...
# 213          자본 [member]|지배기업 소유주지분|기타자본항목    제 50 기   -7931370000000
# 214    자본 [member]|지배기업 소유주지분|매각예정분류기타자본항목    제 50 기
# 215  자본 [member]|지배기업 소유주지분|이익잉여금 [member]    제 50 기  242698956000000
# 216    자본 [member]|지배기업 소유주지분|자본금 [member]    제 50 기     897514000000
# 217         자본 [member]|지배기업 소유주지분|주식발행초과금    제 50 기    4403893000000
#
#     frmtrm_nm    frmtrm_amount bfefrmtrm_nm bfefrmtrm_amount ord  \
# 0      제 49 기  146982464000000       제 48 기  141429704000000   1
# 1      제 49 기   30545130000000       제 48 기   32111442000000   2
# 2      제 49 기   49447696000000       제 48 기   52432411000000   3
# 3      제 49 기    3191375000000       제 48 기    3638460000000   4
# 4      제 49 기                        제 48 기                    5
# ..        ...              ...          ...              ...  ..
# 213    제 49 기  -13899191000000       제 48 기  -11934586000000  19
# 214    제 49 기                        제 48 기     -28810000000  19
# 215    제 49 기  215811200000000       제 48 기  193086317000000  19
# 216    제 49 기     897514000000       제 48 기     897514000000  19
# 217    제 49 기    4403893000000       제 48 기    4403893000000  19
#
#     thstrm_add_amount
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ..                ...
# 213               NaN
# 214               NaN
# 215               NaN
# 216               NaN
# 217               NaN
#
# [218 rows x 17 columns]

# %%
# 삼성전자 2018년 사업보고서
attaches = dart.attach_file_list('20190401004781')
attaches
# Out:
#                                   file_name  \
# 0               [삼성전자]사업보고서(2019.04.01).pdf
# 1       [삼성전자]사업보고서_재무제표(2019.04.01)_ko.xls
# 2  [삼성전자]사업보고서_IFRS(원문XBRL)(2019.04.01).zip
#
#                                                  url   type
# 0  http://dart.fss.or.kr/pdf/download/pdf.do?rcp_...    pdf
# 1  http://dart.fss.or.kr/pdf/download/excel.do?rc...  excel
# 2  http://dart.fss.or.kr/pdf/download/ifrs.do?rcp...   ifrs

# %%
xls_url = attaches.loc[attaches['type']=='excel', 'url'].values[0] # 첨부 재무제표 엑셀
xls_url
# Out:
# 'http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20190401004781&dcm_no=6616741&lang=ko'

# %%
dart.retrieve(xls_url, '삼성전자_2018.xls')
# Out:
# '삼성전자_2018.xls'

# %%
import pandas as pd

xl = pd.ExcelFile('삼성전자_2018.xls')
xl.sheet_names
# Out:
# ['기본정보',
#  '연결 재무상태표',
#  '연결 손익계산서',
#  '연결 포괄손익계산서',
#  '연결 자본변동표',
#  '연결 현금흐름표',
#  '재무상태표',
#  '손익계산서',
#  '포괄손익계산서',
#  '자본변동표',
#  '현금흐름표']

# %%
pd.read_excel('삼성전자_2018.xls', sheet_name='연결 손익계산서', skiprows=6)
# Out:
#                                        제 50 기     제 49 기     제 48 기
# 0                          수익(매출액)  243771415  239575376  201866745
# 1                             매출원가  132394411  129290661  120277715
# 2                            매출총이익  111377004  110284715   81589030
# 3                          판매비와관리비   52490335   56639677   52348358
# 4                         영업이익(손실)   58886669   53645038   29240672
# 5                             기타수익    1485037    3010657    3238261
# 6                             기타비용    1142018    1419648    2463814
# 7                            지분법이익     539845     201442      19501
# 8                             금융수익    9999321    9737391   11385645
# 9                             금융비용    8608896    8978913   10706613
# 10                 법인세비용차감전순이익(손실)   61159958   56195967   30713652
# 11                           법인세비용   16815101   14009220    7987560
# 12                      계속영업이익(손실)   44344857   42186747   22726092
# 13                       당기순이익(손실)   44344857   42186747   22726092
# 14                   당기순이익(손실)의 귀속
# 15      지배기업의 소유주에게 귀속되는 당기순이익(손실)   43890877   41344569   22415655
# 16           비지배지분에 귀속되는 당기순이익(손실)     453980     842178     310437
# 17                            주당이익
# 18             기본주당이익(손실) (단위 : 원)       6461       5997       3159
# 19             희석주당이익(손실) (단위 : 원)       6461       5997       3159

# %%
df = dart.major_shareholders_exec('삼성전자')
df
# Out:
#            rcept_no    rcept_dt corp_code corp_name repror isu_exctv_rgist_at  \
# 0    20191217000015  2019-12-17  00126380      삼성전자    전승준               등기임원
# 1    20191223000108  2019-12-23  00126380      삼성전자    장의영              비등기임원
# 2    20191223000332  2019-12-23  00126380      삼성전자    권오현              비등기임원
# 3    20191224000201  2019-12-24  00126380      삼성전자    최주호              비등기임원
# 4    20191226000283  2019-12-26  00126380      삼성전자    전승준               등기임원
# ..              ...         ...       ...       ...    ...                ...
# 221  20211215000176  2021-12-15  00126380      삼성전자    윤송호              비등기임원
# 222  20211215000364  2021-12-15  00126380      삼성전자    박훈철              비등기임원
# 223  20211215000480  2021-12-15  00126380      삼성전자    노승환              비등기임원
# 224  20211215000412  2021-12-15  00126380      삼성전자    박재범              비등기임원
# 225  20211215000121  2021-12-15  00126380      삼성전자    이정호              비등기임원
#
#     isu_exctv_ofcps isu_main_shrholdr sp_stock_lmp_cnt sp_stock_lmp_irds_cnt  \
# 0                상무                 -           17,800                -9,200
# 1                전무                 -           17,500               -10,000
# 2                회장                 -           17,000                -8,000
# 3               부사장                 -           16,400                -3,700
# 4                상무                 -           17,000                  -800
# ..              ...               ...              ...                   ...
# 221              상무                 -            2,250                 2,250
# 222              상무                 -              391                   391
# 223              상무           10%이상주주              448                   448
# 224              상무                 -              400                   400
# 225              상무                 -                4                     4
#
#     sp_stock_lmp_rate sp_stock_lmp_irds_rate
# 0                0.00                   0.00
# 1                0.00                   0.00
# 2                0.00                   0.00
# 3                0.00                   0.00
# 4                0.00                   0.00
# ..                ...                    ...
# 221              0.00                   0.00
# 222                 0                      0
# 223              0.00                   0.00
# 224              0.00                   0.00
# 225              0.00                   0.00
#
# [226 rows x 12 columns]

# %%
attaches = dart.attach_file_list('20211215000121')
attaches
# Out:
#                                    file_name  \
# 0  [삼성전자]임원ㆍ주요주주특정증권등소유상황보고서(2021.12.15).pdf
#
#                                                  url type
# 0  http://dart.fss.or.kr/pdf/download/pdf.do?rcp_...  pdf

# %%
df[df['rcept_no'] == '20190401004781']
# Out:
# Empty DataFrame
# Columns: [rcept_no, rcept_dt, corp_code, corp_name, repror, isu_exctv_rgist_at, isu_exctv_ofcps, isu_main_shrholdr, sp_stock_lmp_cnt, sp_stock_lmp_irds_cnt, sp_stock_lmp_rate, sp_stock_lmp_irds_rate]
# Index: []

# %%
rcp_no = dart.finstate('Kakao', 2018)
rcp_no
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-5e31caf02b51> in <module>
# ----> 1 rcp_no = dart.finstate('Kakao', 2018)
#       2 rcp_no
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenDartReader\dart.py in finstate(self, corp, bsns_year, reprt_code)
#     104         else:
#     105             corp_code = self.find_corp_code(corp)
# --> 106         return dart_finstate.finstate(self.api_key, corp_code, bsns_year, reprt_code)
#     107
#     108     # 3-3. 재무제표 원본파일(XBRL)
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenDartReader\dart_finstate.py in finstate(api_key, corp_code, bsns_year, reprt_code)
#      19 def finstate(api_key, corp_code, bsns_year, reprt_code='11011'):
#      20     url = 'https://opendart.fss.or.kr/api/'
# ---> 21     url += 'fnlttMultiAcnt.json' if ',' in corp_code else 'fnlttSinglAcnt.json'
#      22
#      23     params = {
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
# 삼성전자 2020년 사업보고서
attaches = dart.attach_file_list(rcp_no)
attaches
# Out:
#                                   file_name  \
# 0               [삼성전자]사업보고서(2021.03.09).pdf
# 1       [삼성전자]사업보고서_재무제표(2021.03.09)_ko.xls
# 2  [삼성전자]사업보고서_IFRS(원문XBRL)(2021.03.09).zip
#
#                                                  url   type
# 0  http://dart.fss.or.kr/pdf/download/pdf.do?rcp_...    pdf
# 1  http://dart.fss.or.kr/pdf/download/excel.do?rc...  excel
# 2  http://dart.fss.or.kr/pdf/download/ifrs.do?rcp...   ifrs

# %%
xls_url = attaches.loc[attaches['type']=='excel', 'url'].values[0] # 첨부 재무제표 엑셀
xls_url
# Out:
# 'http://dart.fss.or.kr/pdf/download/excel.do?rcp_no=20210309000744&dcm_no=7861003&lang=ko'

# %%
import os
import pandas as pd

# %%
file_name = '삼성전자_2020.xls'

dart.retrieve(xls_url, file_name)

df = pd.read_excel(file_name, sheet_name='연결 손익계산서', skiprows=6)

os.remove(file_name)

# %%
os.remove(file_name)

# %%
df[df[' '] == '수익(매출액)']
# Out:
#                제 52 기     제 51 기     제 50 기
# 0  수익(매출액)  236806988  230400881  243771415

# %%
import os
import pandas as pd

# %%
key_word = '010950'

rcp_no = dart.finstate(key_word, 2020).loc[0, 'rcept_no']
# 삼성전자 2020년 사업보고서
attaches = dart.attach_file_list(rcp_no)
# 첨부 재무제표 엑셀
xls_url = attaches.loc[attaches['type']=='excel', 'url'].values[0]

file_name = f'{key_word}_2020.xls'

dart.retrieve(xls_url, file_name)
df = pd.read_excel(file_name, sheet_name='연결 포괄손익계산서', skiprows=6)
# os.remove(file_name)

print('매출액: ', df.iloc[0].values[1])
print('영업이익: ', df.iloc[4].values[1])
print(df[df[' '].isin(['당기순이익(손실)'])].iloc[0].values[1])
# print('당기순이익: ', df['당기순이익' in df[' ']][0].values[1])
# Out:
# 매출액:  16829681
# 영업이익:  -1099146
# -796108
