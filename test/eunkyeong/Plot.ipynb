# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
chart_df = pd.read_csv(r'C:\StockHelper_Project\StockHelper\dataset\정제데이터\특허\count_patent_desc.csv').drop(columns='Unnamed: 0', axis=1)

# %%
chart_df.set_index('키워드', inplace=True)

# %%
chart_df = chart_df[:15]

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
plt.figure(figsize=(25,10))
plt.bar(chart_df.index, chart_df['빈도수'])
# Out:
# <BarContainer object of 15 artists>
