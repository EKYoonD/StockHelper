# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import json
import time
import re
import os
import konlpy.tag
from ckonlpy.tag import Twitter as cTwitter
import wordcloud
import matplotlib.pyplot as plt
# %matplotlib inline
import codecs
from gensim.models import word2vec
from collections import Counter

# %% [markdown]
# ---
# ## [이용 가이드]
#
# #### 첫번째 셀 : 기본설정 및 크롤링
# - 사용자 설정 있음
#
# > `start_page` : 크롤링할 시작 페이지
# > `resresh_unit` : 새로고침 단위 (320 페이지 이상 이동시 크롬 out of memory 발생
# > `stop_page` : 크롤링할 마지막 페이지
# > `file_name` : 저장할 파일명
# - .기호 개당 1초를 의미 <- 사용자 정의 함수 delay(str, int)
#
# #### 두번째 셀 : 데이터 저장
#
# #### 세번째 셀 : 저장된 데이터 확인
# - 윈도우에서 인코딩 형식 디스매칭으로 글자 깨질 때 사용하기에 유용
# - 인덱스 번호와 게시물 번호 매칭하여 데이터 누락/중복 확인 가능
#
# ---

# %%
# 첫번째 셀 : 기본설정
# 크롤링을 위해 사용자가 입력해야 되는 값
start_page = 1    # 크롤링할 시작 페이지
refresh_unit = 200   # 크롤링 후 새로고침할 단위
stop_page = 1111   # 크롤링할 마지막 페이지
file_name = 'patent_{date}_{first_page}_{last_page}.csv'  # 저장할 파일명

# 메인
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.keys import Keys
from IPython.display import Image
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime
import time
import os
import math

# 함수 : 딜레이
def delay(text, sec):
    print(text, end="")
    for i in range(sec): print('.', end=""); time.sleep(1)

# 함수 : 사이트에서 제목/내용 크롤링
current_page_css_selector = 'span.board_pager03 strong'
def contentCrawling(current_page_css_selector = current_page_css_selector):
    dom = BeautifulSoup(driver.page_source, 'html.parser')
    patent_list = dom.select('.search_section article')
    
    current_page = driver.find_element_by_css_selector(current_page_css_selector).text

    result = [
            {
                '제목': patent.select_one('.search_section_title h1 > a:nth-of-type(2)').text.strip(),
                '내용': patent.select_one('.search_txt').text.strip()
            }
            for patent in patent_list
    ]

    return int(current_page), result   # (크롤링한 페이지, 크롤링 결과) 반환

# 함수 : 저장할 파일 경로 찾기
def findPath(file_name):
    file_path = r'D:\DevRoot\StockHelper\dataset'
    file_name = file_name
    try: 
        path = os.path.join(file_path, file_name)
    except(Exception):
        file_path = 'C:\DeepLearning_Project\StockHelper\StockHelper\dataset'
        path = os.path.join(file_path, file_name)
        
    return path

print('프로그램 시작')
start = time.time()  # 시작 시간 저장
result = []

# 1. webdriver를 이용해 kipris 접속
driver_path = r'D:\DevRoot\download\chromedriver.exe'
try: 
    driver = webdriver.Chrome(driver_path)
except(Exception):
    driver_path = r'C:\DevRoot\download\chromedriver.exe'
    driver = webdriver.Chrome(driver_path)

for refreshed_num in range(1, math.ceil(stop_page / refresh_unit) + 1):
    driver.get("http://kpat.kipris.or.kr/kpat/searchLogina.do?next=MainSearch")
    
    # 크롤링 시작페이지 재설정
    if refreshed_num != 1: start_page = refresh_unit * (refreshed_num - 1) + 1
    
    # 2. 검색 옵션 설정
    delay('검색 옵션 설정', 4)

    # 2.1. 행정상태 변경
    # defalut 해제 <- '전체' 클릭
    driver.find_element_by_css_selector('form#leftside .release_list > span:nth-of-type(1) > input').click()
    # 원하는 checkbox만 선택 <- '등록' 클릭
    driver.find_element_by_css_selector('form#leftside .release_list > span:nth-last-of-type(1) > input').click()

    # 2.2. 기간을 검색어로 입력
    today = datetime.today().strftime("%Y%m%d")
    decade = str(int(today) - int('00001000'))
    driver.find_element_by_css_selector('.keyword').send_keys(f'GD=[{decade}~{today}]')
    driver.find_element_by_css_selector('.input_btn img').click()

    # 2.3. 90개씩 보기 선택
    pageSel = 90   # 페이지당 게시물 개수 (30, 60, 90 중 택1)
    select = Select(driver.find_element_by_id('opt28'))
    select.select_by_value(str(pageSel))
    driver.find_element_by_css_selector('#pageSel img').click()

    print('검색 완료')

    # 3. 데이터 추출
    delay('데이터 추출 준비중', 3)
    print('완료')

    page_num = 'span.board_pager03 a:nth-last-of-type({0})'   # target_page 구할 때 이용

    # 3.1. 첫 페이지 크롤링
    current_page, data = contentCrawling()
    if current_page == stop_page: break   # 실행종료
    if current_page != start_page:   # 첫 페이지 찾기
        delay('시작 페이지로 이동', 0)
        while current_page < start_page:
            if current_page // 10 < start_page // 10:
                driver.find_element_by_css_selector(page_num.format(1)).click()
                delay('', 2)
                current_page = int(driver.find_element_by_css_selector(current_page_css_selector).text)
                continue
            for i in range(10, 0, -1):
                driver.find_element_by_css_selector(page_num.format(i)).click()
                delay('', 2)
                current_page = int(driver.find_element_by_css_selector(current_page_css_selector).text)
                if current_page == start_page: print('완료'); break
    current_page, data = contentCrawling()
    result.extend(data)
    print(f'{current_page} 위치 -> {current_page} 페이지 크롤링 완료')

    # 3.2. 페이지 이동하며 크롤링
    while True:
        # 실행 종료
        if current_page >= stop_page: break
        if current_page == refresh_unit * refreshed_num: break

        for i in range(10, 0, -1):
            if current_page >= stop_page: break
            if current_page == refresh_unit * refreshed_num: break

            # 3.2.1. 크롤링할 페이지가 현재 페이지의 다음 페이지인 지 확인
            target_page = driver.find_element_by_css_selector(page_num.format(i))
            if i != 1 and int(target_page.text) <= current_page: delay('', 1); continue 

            print(f'현재 {current_page}', end=" -> ")
            time.sleep(1)
            # 3.2.2. 크롤링할 페이지(target_page)인 다음 페이지로 이동
            print(f'{target_page.text} click', end=" -> ")
            target_page.click()  # 크롤링할 페이지로 이동
            delay('', 2)        
            while True:
                click_page = driver.find_element_by_css_selector(current_page_css_selector).text
    #             try: # (클릭해서 이동한) 현재 페이지(click_page)는 target_page
    #                 click_page = driver.find_element_by_css_selector(current_page_css_selector).text
    #             except KeyboardInterrupt or WebDriverException:
    #                 print('Interrupted')
    #                 try: sys.exit(0)
    #                 except SystemExit: os._exit(0)
    #                 finally:
    #                     print('긁어온 데이터개수 :', len(result))
    #                     print('소요시간 :', int(time.time() - start) / 60, '분')  # 현재시각 - 시작시간 = 실행 시간
    #                     print('프로그램 종료')
    #             except Exception:
    #                 driver.refresh()   # 새로고침
    #                 dealy('', 4)
    #                 dom = BeautifulSoup(driver.page_source, 'html.parser')
    #                 patent_list = dom.select('.search_section article')
    #                 click_page = int(driver.find_element_by_css_selector(current_page_css_selector).text)

                if current_page != click_page: break  # 페이지 이동 시 loop 탈출
                delay("", 2)  # 페이지 이동 안 하면 seelp()
            # 3.2.3. 크롤링
            current_page, data = contentCrawling()
            result.extend(data)
            # 3.2.4. 중간결과 반환
            print(f'{current_page} 페이지 크롤링 완료')

print('=' * 60)
print('긁어온 데이터개수 :', len(result))
print('소요시간 :', int(time.time() - start) / 60, '분')  # 현재시각 - 시작시간 = 실행 시간
print('프로그램 종료')
# Out:
# 프로그램 시작
# 검색 옵션 설정....검색 완료
# 데이터 추출 준비중...완료
# 1 위치 -> 1 페이지 크롤링 완료
# 현재 1 -> 2 click -> ..2 페이지 크롤링 완료
# 현재 2 -> 3 click -> ..3 페이지 크롤링 완료
# 현재 3 -> 4 click -> ..4 페이지 크롤링 완료
# 현재 4 -> 5 click -> ..5 페이지 크롤링 완료
# 현재 5 -> 6 click -> ..6 페이지 크롤링 완료
# 현재 6 -> 7 click -> ..7 페이지 크롤링 완료
# 현재 7 -> 8 click -> ..8 페이지 크롤링 완료
# 현재 8 -> 9 click -> ..9 페이지 크롤링 완료
# 현재 9 -> 10 click -> ..10 페이지 크롤링 완료
# 현재 10 -> 다음 click -> ..11 페이지 크롤링 완료
# 현재 11 -> 12 click -> ..12 페이지 크롤링 완료
# 현재 12 -> 13 click -> ..13 페이지 크롤링 완료
# 현재 13 -> 14 click -> ..14 페이지 크롤링 완료
# 현재 14 -> 15 click -> ..15 페이지 크롤링 완료
# 현재 15 -> 16 click -> ..16 페이지 크롤링 완료
# 현재 16 -> 17 click -> ..17 페이지 크롤링 완료
# 현재 17 -> 18 click -> ..18 페이지 크롤링 완료
# 현재 18 -> 19 click -> ..19 페이지 크롤링 완료
# 현재 19 -> 20 click -> ..20 페이지 크롤링 완료
# 현재 20 -> 다음 click -> ..21 페이지 크롤링 완료
# 현재 21 -> 22 click -> ..22 페이지 크롤링 완료
# 현재 22 -> 23 click -> ..23 페이지 크롤링 완료
# 현재 23 -> 24 click -> ..24 페이지 크롤링 완료
# 현재 24 -> 25 click -> ..25 페이지 크롤링 완료
# 현재 25 -> 26 click -> ..26 페이지 크롤링 완료
# 현재 26 -> 27 click -> ..27 페이지 크롤링 완료
# 현재 27 -> 28 click -> ..28 페이지 크롤링 완료
# 현재 28 -> 29 click -> ..29 페이지 크롤링 완료
# 현재 29 -> 30 click -> ..30 페이지 크롤링 완료
# 현재 30 -> 다음 click -> ..31 페이지 크롤링 완료
# 현재 31 -> 32 click -> ..32 페이지 크롤링 완료
# 현재 32 -> 33 click -> ..33 페이지 크롤링 완료
# 현재 33 -> 34 click -> ..34 페이지 크롤링 완료
# 현재 34 -> 35 click -> ..35 페이지 크롤링 완료
# 현재 35 -> 36 click -> ..36 페이지 크롤링 완료
# 현재 36 -> 37 click -> ..37 페이지 크롤링 완료
# 현재 37 -> 38 click -> ..38 페이지 크롤링 완료
# 현재 38 -> 39 click -> ..39 페이지 크롤링 완료
# 현재 39 -> 40 click -> ..40 페이지 크롤링 완료
# 현재 40 -> 다음 click -> ..41 페이지 크롤링 완료
# 현재 41 -> 42 click -> ..42 페이지 크롤링 완료
# 현재 42 -> 43 click -> ..43 페이지 크롤링 완료
# 현재 43 -> 44 click -> ..44 페이지 크롤링 완료
# 현재 44 -> 45 click -> ..45 페이지 크롤링 완료
# 현재 45 -> 46 click -> ..46 페이지 크롤링 완료
# 현재 46 -> 47 click -> ..47 페이지 크롤링 완료
# 현재 47 -> 48 click -> ..48 페이지 크롤링 완료
# 현재 48 -> 49 click -> ..49 페이지 크롤링 완료
# 현재 49 -> 50 click -> ..50 페이지 크롤링 완료
# 현재 50 -> 다음 click -> ..51 페이지 크롤링 완료
# 현재 51 -> 52 click -> ..52 페이지 크롤링 완료
# 현재 52 -> 53 click -> ..53 페이지 크롤링 완료
# 현재 53 -> 54 click -> ..54 페이지 크롤링 완료
# 현재 54 -> 55 click -> ..55 페이지 크롤링 완료
# 현재 55 -> 56 click -> ..56 페이지 크롤링 완료
# 현재 56 -> 57 click -> ..57 페이지 크롤링 완료
# 현재 57 -> 58 click -> ..58 페이지 크롤링 완료
# 현재 58 -> 59 click -> ..59 페이지 크롤링 완료
# 현재 59 -> 60 click -> ..60 페이지 크롤링 완료
# 현재 60 -> 다음 click -> ..61 페이지 크롤링 완료
# 현재 61 -> 62 click -> ..62 페이지 크롤링 완료
# 현재 62 -> 63 click -> ..63 페이지 크롤링 완료
# 현재 63 -> 64 click -> ..64 페이지 크롤링 완료
# 현재 64 -> 65 click -> ..65 페이지 크롤링 완료
# 현재 65 -> 66 click -> ..66 페이지 크롤링 완료
# 현재 66 -> 67 click -> ..67 페이지 크롤링 완료
# 현재 67 -> 68 click -> ..68 페이지 크롤링 완료
# 현재 68 -> 69 click -> ..69 페이지 크롤링 완료
# 현재 69 -> 70 click -> ..70 페이지 크롤링 완료
# 현재 70 -> 다음 click -> ..71 페이지 크롤링 완료
# 현재 71 -> 72 click -> ..72 페이지 크롤링 완료
# 현재 72 -> 73 click -> ..73 페이지 크롤링 완료
# 현재 73 -> 74 click -> ..74 페이지 크롤링 완료
# 현재 74 -> 75 click -> ..75 페이지 크롤링 완료
# 현재 75 -> 76 click -> ..76 페이지 크롤링 완료
# 현재 76 -> 77 click -> ..77 페이지 크롤링 완료
# 현재 77 -> 78 click -> ..78 페이지 크롤링 완료
# 현재 78 -> 79 click -> ..79 페이지 크롤링 완료
# 현재 79 -> 80 click -> ..80 페이지 크롤링 완료
# 현재 80 -> 다음 click -> ..81 페이지 크롤링 완료
# 현재 81 -> 82 click -> ..82 페이지 크롤링 완료
# 현재 82 -> 83 click -> ..83 페이지 크롤링 완료
# 현재 83 -> 84 click -> ..84 페이지 크롤링 완료
# 현재 84 -> 85 click -> ..85 페이지 크롤링 완료
# 현재 85 -> 86 click -> ..86 페이지 크롤링 완료
# 현재 86 -> 87 click -> ..87 페이지 크롤링 완료
# 현재 87 -> 88 click -> ..88 페이지 크롤링 완료
# 현재 88 -> 89 click -> ..89 페이지 크롤링 완료
# 현재 89 -> 90 click -> ..90 페이지 크롤링 완료
# 현재 90 -> 다음 click -> ..91 페이지 크롤링 완료
# 현재 91 -> 92 click -> ..92 페이지 크롤링 완료
# 현재 92 -> 93 click -> ..93 페이지 크롤링 완료
# 현재 93 -> 94 click -> ..94 페이지 크롤링 완료
# 현재 94 -> 95 click -> ..95 페이지 크롤링 완료
# 현재 95 -> 96 click -> ..96 페이지 크롤링 완료
# 현재 96 -> 97 click -> ..97 페이지 크롤링 완료
# 현재 97 -> 98 click -> ..98 페이지 크롤링 완료
# 현재 98 -> 99 click -> ..99 페이지 크롤링 완료
# 현재 99 -> 100 click -> ..100 페이지 크롤링 완료
# 현재 100 -> 다음 click -> ..101 페이지 크롤링 완료
# 현재 101 -> 102 click -> ..102 페이지 크롤링 완료
# 현재 102 -> 103 click -> ..103 페이지 크롤링 완료
# 현재 103 -> 104 click -> ..104 페이지 크롤링 완료
# 현재 104 -> 105 click -> ..105 페이지 크롤링 완료
# 현재 105 -> 106 click -> ..106 페이지 크롤링 완료
# 현재 106 -> 107 click -> ..107 페이지 크롤링 완료
# 현재 107 -> 108 click -> ..108 페이지 크롤링 완료
# 현재 108 -> 109 click -> ..109 페이지 크롤링 완료
# 현재 109 -> 110 click -> ..110 페이지 크롤링 완료
# 현재 110 -> 다음 click -> ..111 페이지 크롤링 완료
# 현재 111 -> 112 click -> ..112 페이지 크롤링 완료
# 현재 112 -> 113 click -> ..113 페이지 크롤링 완료
# 현재 113 -> 114 click -> ..114 페이지 크롤링 완료
# 현재 114 -> 115 click -> ..115 페이지 크롤링 완료
# 현재 115 -> 116 click -> ..116 페이지 크롤링 완료
# 현재 116 -> 117 click -> ..117 페이지 크롤링 완료
# 현재 117 -> 118 click -> ..118 페이지 크롤링 완료
# 현재 118 -> 119 click -> ..119 페이지 크롤링 완료
# 현재 119 -> 120 click -> ..120 페이지 크롤링 완료
# 현재 120 -> 다음 click -> ..121 페이지 크롤링 완료
# 현재 121 -> 122 click -> ..122 페이지 크롤링 완료
# 현재 122 -> 123 click -> ..123 페이지 크롤링 완료
# 현재 123 -> 124 click -> ..124 페이지 크롤링 완료
# 현재 124 -> 125 click -> ..125 페이지 크롤링 완료
# 현재 125 -> 126 click -> ..126 페이지 크롤링 완료
# 현재 126 -> 127 click -> ..127 페이지 크롤링 완료
# 현재 127 -> 128 click -> ..128 페이지 크롤링 완료
# 현재 128 -> 129 click -> ..129 페이지 크롤링 완료
# 현재 129 -> 130 click -> ..130 페이지 크롤링 완료
# 현재 130 -> 다음 click -> ..131 페이지 크롤링 완료
# 현재 131 -> 132 click -> ..132 페이지 크롤링 완료
# 현재 132 -> 133 click -> ..133 페이지 크롤링 완료
# 현재 133 -> 134 click -> ..134 페이지 크롤링 완료
# 현재 134 -> 135 click -> ..135 페이지 크롤링 완료
# 현재 135 -> 136 click -> ..136 페이지 크롤링 완료
# 현재 136 -> 137 click -> ..137 페이지 크롤링 완료
# 현재 137 -> 138 click -> ..138 페이지 크롤링 완료
# 현재 138 -> 139 click -> ..139 페이지 크롤링 완료
# 현재 139 -> 140 click -> ..140 페이지 크롤링 완료
# 현재 140 -> 다음 click -> ..141 페이지 크롤링 완료
# 현재 141 -> 142 click -> ..142 페이지 크롤링 완료
# 현재 142 -> 143 click -> ..143 페이지 크롤링 완료
# 현재 143 -> 144 click -> ..144 페이지 크롤링 완료
# 현재 144 -> 145 click -> ..145 페이지 크롤링 완료
# 현재 145 -> 146 click -> ..146 페이지 크롤링 완료
# 현재 146 -> 147 click -> ..147 페이지 크롤링 완료
# 현재 147 -> 148 click -> ..148 페이지 크롤링 완료
# 현재 148 -> 149 click -> ..149 페이지 크롤링 완료
# 현재 149 -> 150 click -> ..150 페이지 크롤링 완료
# 현재 150 -> 다음 click -> ..151 페이지 크롤링 완료
# 현재 151 -> 152 click -> ..152 페이지 크롤링 완료
# 현재 152 -> 153 click -> ..153 페이지 크롤링 완료
# 현재 153 -> 154 click -> ..154 페이지 크롤링 완료
# 현재 154 -> 155 click -> ..155 페이지 크롤링 완료
# 현재 155 -> 156 click -> ..156 페이지 크롤링 완료
# 현재 156 -> 157 click -> ..157 페이지 크롤링 완료
# 현재 157 -> 158 click -> ..158 페이지 크롤링 완료
# 현재 158 -> 159 click -> ..159 페이지 크롤링 완료
# 현재 159 -> 160 click -> ..160 페이지 크롤링 완료
# 현재 160 -> 다음 click -> ..161 페이지 크롤링 완료
# 현재 161 -> 162 click -> ..162 페이지 크롤링 완료
# 현재 162 -> 163 click -> ..163 페이지 크롤링 완료
# 현재 163 -> 164 click -> ..164 페이지 크롤링 완료
# 현재 164 -> 165 click -> ..165 페이지 크롤링 완료
# 현재 165 -> 166 click -> ..166 페이지 크롤링 완료
# 현재 166 -> 167 click -> ..167 페이지 크롤링 완료
# 현재 167 -> 168 click -> ..168 페이지 크롤링 완료
# 현재 168 -> 169 click -> ..169 페이지 크롤링 완료
# 현재 169 -> 170 click -> ..170 페이지 크롤링 완료
# 현재 170 -> 다음 click -> ..171 페이지 크롤링 완료
# 현재 171 -> 172 click -> ..172 페이지 크롤링 완료
# 현재 172 -> 173 click -> ..173 페이지 크롤링 완료
# 현재 173 -> 174 click -> ..174 페이지 크롤링 완료
# 현재 174 -> 175 click -> ..175 페이지 크롤링 완료
# 현재 175 -> 176 click -> ..176 페이지 크롤링 완료
# 현재 176 -> 177 click -> ..177 페이지 크롤링 완료
# 현재 177 -> 178 click -> ..178 페이지 크롤링 완료
# 현재 178 -> 179 click -> ..179 페이지 크롤링 완료
# 현재 179 -> 180 click -> ..180 페이지 크롤링 완료
# 현재 180 -> 다음 click -> ..181 페이지 크롤링 완료
# 현재 181 -> 182 click -> ..182 페이지 크롤링 완료
# 현재 182 -> 183 click -> ..183 페이지 크롤링 완료
# 현재 183 -> 184 click -> ..184 페이지 크롤링 완료
# 현재 184 -> 185 click -> ..185 페이지 크롤링 완료
# 현재 185 -> 186 click -> ..186 페이지 크롤링 완료
# 현재 186 -> 187 click -> ..187 페이지 크롤링 완료
# 현재 187 -> 188 click -> ..188 페이지 크롤링 완료
# 현재 188 -> 189 click -> ..189 페이지 크롤링 완료
# 현재 189 -> 190 click -> ..190 페이지 크롤링 완료
# 현재 190 -> 다음 click -> ..191 페이지 크롤링 완료
# 현재 191 -> 192 click -> ..192 페이지 크롤링 완료
# 현재 192 -> 193 click -> ..193 페이지 크롤링 완료
# 현재 193 -> 194 click -> ..194 페이지 크롤링 완료
# 현재 194 -> 195 click -> ..195 페이지 크롤링 완료
# 현재 195 -> 196 click -> ..196 페이지 크롤링 완료
# 현재 196 -> 197 click -> ..197 페이지 크롤링 완료
# 현재 197 -> 198 click -> ..198 페이지 크롤링 완료
# 현재 198 -> 199 click -> ..199 페이지 크롤링 완료
# 현재 199 -> 200 click -> ..200 페이지 크롤링 완료
# 검색 옵션 설정....검색 완료
# 데이터 추출 준비중...완료
# 시작 페이지로 이동........................................201 위치 -> 201 페이지 크롤링 완료
# 현재 201 -> 202 click -> ..202 페이지 크롤링 완료
# 현재 202 -> 203 click -> ..203 페이지 크롤링 완료
# 현재 203 -> 204 click -> ..204 페이지 크롤링 완료
# 현재 204 -> 205 click -> ..205 페이지 크롤링 완료
# 현재 205 -> 206 click -> ..206 페이지 크롤링 완료
# 현재 206 -> 207 click -> ..207 페이지 크롤링 완료
# 현재 207 -> 208 click -> ..208 페이지 크롤링 완료
# 현재 208 -> 209 click -> ..209 페이지 크롤링 완료
# 현재 209 -> 210 click -> ..210 페이지 크롤링 완료
# 현재 210 -> 다음 click -> ..211 페이지 크롤링 완료
# 현재 211 -> 212 click -> ..212 페이지 크롤링 완료
# 현재 212 -> 213 click -> ..213 페이지 크롤링 완료
# 현재 213 -> 214 click -> ..214 페이지 크롤링 완료
# 현재 214 -> 215 click -> ..215 페이지 크롤링 완료
# 현재 215 -> 216 click -> ..216 페이지 크롤링 완료
# 현재 216 -> 217 click -> ..217 페이지 크롤링 완료
# 현재 217 -> 218 click -> ..218 페이지 크롤링 완료
# 현재 218 -> 219 click -> ..219 페이지 크롤링 완료
# 현재 219 -> 220 click -> ..220 페이지 크롤링 완료
# 현재 220 -> 다음 click -> ..221 페이지 크롤링 완료
# 현재 221 -> 222 click -> ..222 페이지 크롤링 완료
# 현재 222 -> 223 click -> ..223 페이지 크롤링 완료
# 현재 223 -> 224 click -> ..224 페이지 크롤링 완료
# 현재 224 -> 225 click -> ..225 페이지 크롤링 완료
# 현재 225 -> 226 click -> ..226 페이지 크롤링 완료
# 현재 226 -> 227 click -> ..227 페이지 크롤링 완료
# 현재 227 -> 228 click -> ..228 페이지 크롤링 완료
# 현재 228 -> 229 click -> ..229 페이지 크롤링 완료
# 현재 229 -> 230 click -> ..230 페이지 크롤링 완료
# 현재 230 -> 다음 click -> ..231 페이지 크롤링 완료
# 현재 231 -> 232 click -> ..232 페이지 크롤링 완료
# 현재 232 -> 233 click -> ..233 페이지 크롤링 완료
# 현재 233 -> 234 click -> ..234 페이지 크롤링 완료
# 현재 234 -> 235 click -> ..235 페이지 크롤링 완료
# 현재 235 -> 236 click -> ..236 페이지 크롤링 완료
# 현재 236 -> 237 click -> ..237 페이지 크롤링 완료
# 현재 237 -> 238 click -> ..238 페이지 크롤링 완료
# 현재 238 -> 239 click -> ..239 페이지 크롤링 완료
# 현재 239 -> 240 click -> ..240 페이지 크롤링 완료
# 현재 240 -> 다음 click -> ..241 페이지 크롤링 완료
# 현재 241 -> 242 click -> ..242 페이지 크롤링 완료
# 현재 242 -> 243 click -> ..243 페이지 크롤링 완료
# 현재 243 -> 244 click -> ..244 페이지 크롤링 완료
# 현재 244 -> 245 click -> ..245 페이지 크롤링 완료
# 현재 245 -> 246 click -> ..246 페이지 크롤링 완료
# 현재 246 -> 247 click -> ..247 페이지 크롤링 완료
# 현재 247 -> 248 click -> ..248 페이지 크롤링 완료
# 현재 248 -> 249 click -> ..249 페이지 크롤링 완료
# 현재 249 -> 250 click -> ..250 페이지 크롤링 완료
# 현재 250 -> 다음 click -> ..251 페이지 크롤링 완료
# 현재 251 -> 252 click -> ..252 페이지 크롤링 완료
# 현재 252 -> 253 click -> ..253 페이지 크롤링 완료
# 현재 253 -> 254 click -> ..254 페이지 크롤링 완료
# 현재 254 -> 255 click -> ..255 페이지 크롤링 완료
# 현재 255 -> 256 click -> ..256 페이지 크롤링 완료
# 현재 256 -> 257 click -> ..257 페이지 크롤링 완료
# 현재 257 -> 258 click -> ..258 페이지 크롤링 완료
# 현재 258 -> 259 click -> ..259 페이지 크롤링 완료
# 현재 259 -> 260 click -> ..260 페이지 크롤링 완료
# 현재 260 -> 다음 click -> ..261 페이지 크롤링 완료
# 현재 261 -> 262 click -> ..262 페이지 크롤링 완료
# 현재 262 -> 263 click -> ..263 페이지 크롤링 완료
# 현재 263 -> 264 click -> ..264 페이지 크롤링 완료
# 현재 264 -> 265 click -> ..265 페이지 크롤링 완료
# 현재 265 -> 266 click -> ..266 페이지 크롤링 완료
# 현재 266 -> 267 click -> ..267 페이지 크롤링 완료
# 현재 267 -> 268 click -> ..268 페이지 크롤링 완료
# 현재 268 -> 269 click -> ..269 페이지 크롤링 완료
# 현재 269 -> 270 click -> ..270 페이지 크롤링 완료
# 현재 270 -> 다음 click -> ..271 페이지 크롤링 완료
# 현재 271 -> 272 click -> ..272 페이지 크롤링 완료
# 현재 272 -> 273 click -> ..273 페이지 크롤링 완료
# 현재 273 -> 274 click -> ..274 페이지 크롤링 완료
# 현재 274 -> 275 click -> ..275 페이지 크롤링 완료
# 현재 275 -> 276 click -> ..276 페이지 크롤링 완료
# 현재 276 -> 277 click -> ..277 페이지 크롤링 완료
# 현재 277 -> 278 click -> ..278 페이지 크롤링 완료
# 현재 278 -> 279 click -> ..279 페이지 크롤링 완료
# 현재 279 -> 280 click -> ..280 페이지 크롤링 완료
# 현재 280 -> 다음 click -> ..281 페이지 크롤링 완료
# 현재 281 -> 282 click -> ..282 페이지 크롤링 완료
# 현재 282 -> 283 click -> ..283 페이지 크롤링 완료
# 현재 283 -> 284 click -> ..284 페이지 크롤링 완료
# 현재 284 -> 285 click -> ..285 페이지 크롤링 완료
# 현재 285 -> 286 click -> ..286 페이지 크롤링 완료
# 현재 286 -> 287 click -> ..287 페이지 크롤링 완료
# 현재 287 -> 288 click -> ..288 페이지 크롤링 완료
# 현재 288 -> 289 click -> ..289 페이지 크롤링 완료
# 현재 289 -> 290 click -> ..290 페이지 크롤링 완료
# 현재 290 -> 다음 click -> ..291 페이지 크롤링 완료
# 현재 291 -> 292 click -> ..292 페이지 크롤링 완료
# 현재 292 -> 293 click -> ..293 페이지 크롤링 완료
# 현재 293 -> 294 click -> ..294 페이지 크롤링 완료
# 현재 294 -> 295 click -> ..295 페이지 크롤링 완료
# 현재 295 -> 296 click -> ..296 페이지 크롤링 완료
# 현재 296 -> 297 click -> ..297 페이지 크롤링 완료
# 현재 297 -> 298 click -> ..298 페이지 크롤링 완료
# 현재 298 -> 299 click -> ..299 페이지 크롤링 완료
# 현재 299 -> 300 click -> ..300 페이지 크롤링 완료
# 현재 300 -> 다음 click -> ..301 페이지 크롤링 완료
# 현재 301 -> 302 click -> ..302 페이지 크롤링 완료
# 현재 302 -> 303 click -> ..303 페이지 크롤링 완료
# 현재 303 -> 304 click -> ..304 페이지 크롤링 완료
# 현재 304 -> 305 click -> ..305 페이지 크롤링 완료
# 현재 305 -> 306 click -> ..306 페이지 크롤링 완료
# 현재 306 -> 307 click -> ..307 페이지 크롤링 완료
# 현재 307 -> 308 click -> ..308 페이지 크롤링 완료
# 현재 308 -> 309 click -> ..309 페이지 크롤링 완료
# 현재 309 -> 310 click -> ..310 페이지 크롤링 완료
# 현재 310 -> 다음 click -> ..311 페이지 크롤링 완료
# 현재 311 -> 312 click -> ..312 페이지 크롤링 완료
# 현재 312 -> 313 click -> ..313 페이지 크롤링 완료
# 현재 313 -> 314 click -> ..314 페이지 크롤링 완료
# 현재 314 -> 315 click -> ..315 페이지 크롤링 완료
# 현재 315 -> 316 click -> ..316 페이지 크롤링 완료
# 현재 316 -> 317 click -> ..317 페이지 크롤링 완료
# 현재 317 -> 318 click -> ..318 페이지 크롤링 완료
# 현재 318 -> 319 click -> ..319 페이지 크롤링 완료
# 현재 319 -> 320 click -> ..320 페이지 크롤링 완료
# 현재 320 -> 다음 click -> ..321 페이지 크롤링 완료
# 현재 321 -> 322 click -> ..322 페이지 크롤링 완료
# 현재 322 -> 323 click -> ..323 페이지 크롤링 완료
# 현재 323 -> 324 click -> ..324 페이지 크롤링 완료
# 현재 324 -> 325 click -> ..325 페이지 크롤링 완료
# 현재 325 -> 326 click -> ..326 페이지 크롤링 완료
# 현재 326 -> 327 click -> ..327 페이지 크롤링 완료
# 현재 327 -> 328 click -> ..328 페이지 크롤링 완료
# 현재 328 -> 329 click -> ..329 페이지 크롤링 완료
# 현재 329 -> 330 click -> ..330 페이지 크롤링 완료
# 현재 330 -> 다음 click -> ..331 페이지 크롤링 완료
# 현재 331 -> 332 click -> ..332 페이지 크롤링 완료
# 현재 332 -> 333 click -> ..333 페이지 크롤링 완료
# 현재 333 -> 334 click -> ..334 페이지 크롤링 완료
# 현재 334 -> 335 click -> ..335 페이지 크롤링 완료
# 현재 335 -> 336 click -> ..336 페이지 크롤링 완료
# 현재 336 -> 337 click -> ..337 페이지 크롤링 완료
# 현재 337 -> 338 click -> ..338 페이지 크롤링 완료
# 현재 338 -> 339 click -> ..339 페이지 크롤링 완료
# 현재 339 -> 340 click -> ..340 페이지 크롤링 완료
# 현재 340 -> 다음 click -> ..341 페이지 크롤링 완료
# 현재 341 -> 342 click -> ..342 페이지 크롤링 완료
# 현재 342 -> 343 click -> ..343 페이지 크롤링 완료
# 현재 343 -> 344 click -> ..344 페이지 크롤링 완료
# 현재 344 -> 345 click -> ..345 페이지 크롤링 완료
# 현재 345 -> 346 click -> ..346 페이지 크롤링 완료
# 현재 346 -> 347 click -> ..347 페이지 크롤링 완료
# 현재 347 -> 348 click -> ..348 페이지 크롤링 완료
# 현재 348 -> 349 click -> ..349 페이지 크롤링 완료
# 현재 349 -> 350 click -> ..350 페이지 크롤링 완료
# 현재 350 -> 다음 click -> ..351 페이지 크롤링 완료
# 현재 351 -> 352 click -> ..352 페이지 크롤링 완료
# 현재 352 -> 353 click -> ..353 페이지 크롤링 완료
# 현재 353 -> 354 click -> ..354 페이지 크롤링 완료
# 현재 354 -> 355 click -> ..355 페이지 크롤링 완료
# 현재 355 -> 356 click -> ..356 페이지 크롤링 완료
# 현재 356 -> 357 click -> ..357 페이지 크롤링 완료
# 현재 357 -> 358 click -> ..358 페이지 크롤링 완료
# 현재 358 -> 359 click -> ..359 페이지 크롤링 완료
# 현재 359 -> 360 click -> ..360 페이지 크롤링 완료
# 현재 360 -> 다음 click -> ..361 페이지 크롤링 완료
# 현재 361 -> 362 click -> ..362 페이지 크롤링 완료
# 현재 362 -> 363 click -> ..363 페이지 크롤링 완료
# 현재 363 -> 364 click -> ..364 페이지 크롤링 완료
# 현재 364 -> 365 click -> ..365 페이지 크롤링 완료
# 현재 365 -> 366 click -> ..366 페이지 크롤링 완료
# 현재 366 -> 367 click -> ..367 페이지 크롤링 완료
# 현재 367 -> 368 click -> ..368 페이지 크롤링 완료
# 현재 368 -> 369 click -> ..369 페이지 크롤링 완료
# 현재 369 -> 370 click -> ..370 페이지 크롤링 완료
# 현재 370 -> 다음 click -> ..371 페이지 크롤링 완료
# 현재 371 -> 372 click -> ..372 페이지 크롤링 완료
# 현재 372 -> 373 click -> ..373 페이지 크롤링 완료
# 현재 373 -> 374 click -> ..374 페이지 크롤링 완료
# 현재 374 -> 375 click -> ..375 페이지 크롤링 완료
# 현재 375 -> 376 click -> ..376 페이지 크롤링 완료
# 현재 376 -> 377 click -> ..377 페이지 크롤링 완료
# 현재 377 -> 378 click -> ..378 페이지 크롤링 완료
# 현재 378 -> 379 click -> ..379 페이지 크롤링 완료
# 현재 379 -> 380 click -> ..380 페이지 크롤링 완료
# 현재 380 -> 다음 click -> ..381 페이지 크롤링 완료
# 현재 381 -> 382 click -> ..382 페이지 크롤링 완료
# 현재 382 -> 383 click -> ..383 페이지 크롤링 완료
# 현재 383 -> 384 click -> ..384 페이지 크롤링 완료
# 현재 384 -> 385 click -> ..385 페이지 크롤링 완료
# 현재 385 -> 386 click -> ..386 페이지 크롤링 완료
# 현재 386 -> 387 click -> ..387 페이지 크롤링 완료
# 현재 387 -> 388 click -> ..388 페이지 크롤링 완료
# 현재 388 -> 389 click -> ..389 페이지 크롤링 완료
# 현재 389 -> 390 click -> ..390 페이지 크롤링 완료
# 현재 390 -> 다음 click -> ..391 페이지 크롤링 완료
# 현재 391 -> 392 click -> ..392 페이지 크롤링 완료
# 현재 392 -> 393 click -> ..393 페이지 크롤링 완료
# 현재 393 -> 394 click -> ..394 페이지 크롤링 완료
# 현재 394 -> 395 click -> ..395 페이지 크롤링 완료
# 현재 395 -> 396 click -> ..396 페이지 크롤링 완료
# 현재 396 -> 397 click -> ..397 페이지 크롤링 완료
# 현재 397 -> 398 click -> ..398 페이지 크롤링 완료
# 현재 398 -> 399 click -> ..399 페이지 크롤링 완료
# 현재 399 -> 400 click -> ..400 페이지 크롤링 완료
# 검색 옵션 설정....검색 완료
# 데이터 추출 준비중...완료
# 시작 페이지로 이동................................................................................401 위치 -> 401 페이지 크롤링 완료
# 현재 401 -> 402 click -> ..402 페이지 크롤링 완료
# 현재 402 -> 403 click -> ..403 페이지 크롤링 완료
# 현재 403 -> 404 click -> ..404 페이지 크롤링 완료
# 현재 404 -> 405 click -> ..405 페이지 크롤링 완료
# 현재 405 -> 406 click -> ..406 페이지 크롤링 완료
# 현재 406 -> 407 click -> ..407 페이지 크롤링 완료
# 현재 407 -> 408 click -> ..408 페이지 크롤링 완료
# 현재 408 -> 409 click -> ..409 페이지 크롤링 완료
# 현재 409 -> 410 click -> ..410 페이지 크롤링 완료
# 현재 410 -> 다음 click -> ..411 페이지 크롤링 완료
# 현재 411 -> 412 click -> ..412 페이지 크롤링 완료
# 현재 412 -> 413 click -> ..413 페이지 크롤링 완료
# 현재 413 -> 414 click -> ..414 페이지 크롤링 완료
# 현재 414 -> 415 click -> ..415 페이지 크롤링 완료
# 현재 415 -> 416 click -> ..416 페이지 크롤링 완료
# 현재 416 -> 417 click -> ..417 페이지 크롤링 완료
# 현재 417 -> 418 click -> ..418 페이지 크롤링 완료
# 현재 418 -> 419 click -> ..419 페이지 크롤링 완료
# 현재 419 -> 420 click -> ..420 페이지 크롤링 완료
# 현재 420 -> 다음 click -> ..421 페이지 크롤링 완료
# 현재 421 -> 422 click -> ..422 페이지 크롤링 완료
# 현재 422 -> 423 click -> ..423 페이지 크롤링 완료
# 현재 423 -> 424 click -> ..424 페이지 크롤링 완료
# 현재 424 -> 425 click -> ..425 페이지 크롤링 완료
# 현재 425 -> 426 click -> ..426 페이지 크롤링 완료
# 현재 426 -> 427 click -> ..427 페이지 크롤링 완료
# 현재 427 -> 428 click -> ..428 페이지 크롤링 완료
# 현재 428 -> 429 click -> ..429 페이지 크롤링 완료
# 현재 429 -> 430 click -> ..430 페이지 크롤링 완료
# 현재 430 -> 다음 click -> ..431 페이지 크롤링 완료
# 현재 431 -> 432 click -> ..432 페이지 크롤링 완료
# 현재 432 -> 433 click -> ..433 페이지 크롤링 완료
# 현재 433 -> 434 click -> ..434 페이지 크롤링 완료
# 현재 434 -> 435 click -> ..435 페이지 크롤링 완료
# 현재 435 -> 436 click -> ..436 페이지 크롤링 완료
# 현재 436 -> 437 click -> ..437 페이지 크롤링 완료
# 현재 437 -> 438 click -> ..438 페이지 크롤링 완료
# 현재 438 -> 439 click -> ..439 페이지 크롤링 완료
# 현재 439 -> 440 click -> ..440 페이지 크롤링 완료
# 현재 440 -> 다음 click -> ..441 페이지 크롤링 완료
# 현재 441 -> 442 click -> ..442 페이지 크롤링 완료
# 현재 442 -> 443 click -> ..443 페이지 크롤링 완료
# 현재 443 -> 444 click -> ..444 페이지 크롤링 완료
# 현재 444 -> 445 click -> ..445 페이지 크롤링 완료
# 현재 445 -> 446 click -> ..446 페이지 크롤링 완료
# 현재 446 -> 447 click -> ..447 페이지 크롤링 완료
# 현재 447 -> 448 click -> ..448 페이지 크롤링 완료
# 현재 448 -> 449 click -> ..449 페이지 크롤링 완료
# 현재 449 -> 450 click -> ..450 페이지 크롤링 완료
# 현재 450 -> 다음 click -> ..451 페이지 크롤링 완료
# 현재 451 -> 452 click -> ..452 페이지 크롤링 완료
# 현재 452 -> 453 click -> ..453 페이지 크롤링 완료
# 현재 453 -> 454 click -> ..454 페이지 크롤링 완료
# 현재 454 -> 455 click -> ..455 페이지 크롤링 완료
# 현재 455 -> 456 click -> ..456 페이지 크롤링 완료
# 현재 456 -> 457 click -> ..457 페이지 크롤링 완료
# 현재 457 -> 458 click -> ..458 페이지 크롤링 완료
# 현재 458 -> 459 click -> ..459 페이지 크롤링 완료
# 현재 459 -> 460 click -> ..460 페이지 크롤링 완료
# 현재 460 -> 다음 click -> ..461 페이지 크롤링 완료
# 현재 461 -> 462 click -> ..462 페이지 크롤링 완료
# 현재 462 -> 463 click -> ..463 페이지 크롤링 완료
# 현재 463 -> 464 click -> ..464 페이지 크롤링 완료
# 현재 464 -> 465 click -> ..465 페이지 크롤링 완료
# 현재 465 -> 466 click -> ..466 페이지 크롤링 완료
# 현재 466 -> 467 click -> ..467 페이지 크롤링 완료
# 현재 467 -> 468 click -> ..468 페이지 크롤링 완료
# 현재 468 -> 469 click -> ..469 페이지 크롤링 완료
# 현재 469 -> 470 click -> ..470 페이지 크롤링 완료
# 현재 470 -> 다음 click -> ..471 페이지 크롤링 완료
# 현재 471 -> 472 click -> ..472 페이지 크롤링 완료
# 현재 472 -> 473 click -> ..473 페이지 크롤링 완료
# 현재 473 -> 474 click -> ..474 페이지 크롤링 완료
# 현재 474 -> 475 click -> ..475 페이지 크롤링 완료
# 현재 475 -> 476 click -> ..476 페이지 크롤링 완료
# 현재 476 -> 477 click -> ..477 페이지 크롤링 완료
# 현재 477 -> 478 click -> ..478 페이지 크롤링 완료
# 현재 478 -> 479 click -> ..479 페이지 크롤링 완료
# 현재 479 -> 480 click -> ..480 페이지 크롤링 완료
# 현재 480 -> 다음 click -> ..481 페이지 크롤링 완료
# 현재 481 -> 482 click -> ..482 페이지 크롤링 완료
# 현재 482 -> 483 click -> ..483 페이지 크롤링 완료
# 현재 483 -> 484 click -> ..484 페이지 크롤링 완료
# 현재 484 -> 485 click -> ..485 페이지 크롤링 완료
# 현재 485 -> 486 click -> ..486 페이지 크롤링 완료
# 현재 486 -> 487 click -> ..487 페이지 크롤링 완료
# 현재 487 -> 488 click -> ..488 페이지 크롤링 완료
# 현재 488 -> 489 click -> ..489 페이지 크롤링 완료
# 현재 489 -> 490 click -> ..490 페이지 크롤링 완료
# 현재 490 -> 다음 click -> ..491 페이지 크롤링 완료
# 현재 491 -> 492 click -> ..492 페이지 크롤링 완료
# 현재 492 -> 493 click -> ..493 페이지 크롤링 완료
# 현재 493 -> 494 click -> ..494 페이지 크롤링 완료
# 현재 494 -> 495 click -> ..495 페이지 크롤링 완료
# 현재 495 -> 496 click -> ..496 페이지 크롤링 완료
# 현재 496 -> 497 click -> ..497 페이지 크롤링 완료
# 현재 497 -> 498 click -> ..498 페이지 크롤링 완료
# 현재 498 -> 499 click -> ..499 페이지 크롤링 완료
# 현재 499 -> 500 click -> ..500 페이지 크롤링 완료
# 현재 500 -> 다음 click -> ..501 페이지 크롤링 완료
# 현재 501 -> 502 click -> ..502 페이지 크롤링 완료
# 현재 502 -> 503 click -> ..503 페이지 크롤링 완료
# 현재 503 -> 504 click -> ..504 페이지 크롤링 완료
# 현재 504 -> 505 click -> ..505 페이지 크롤링 완료
# 현재 505 -> 506 click -> ..506 페이지 크롤링 완료
# 현재 506 -> 507 click -> ..507 페이지 크롤링 완료
# 현재 507 -> 508 click -> ..508 페이지 크롤링 완료
# 현재 508 -> 509 click -> ..509 페이지 크롤링 완료
# 현재 509 -> 510 click -> ..510 페이지 크롤링 완료
# 현재 510 -> 다음 click -> ..511 페이지 크롤링 완료
# 현재 511 -> 512 click -> ..512 페이지 크롤링 완료
# 현재 512 -> 513 click -> ..513 페이지 크롤링 완료
# 현재 513 -> 514 click -> ..514 페이지 크롤링 완료
# 현재 514 -> 515 click -> ..515 페이지 크롤링 완료
# 현재 515 -> 516 click -> ..516 페이지 크롤링 완료
# 현재 516 -> 517 click -> ..517 페이지 크롤링 완료
# 현재 517 -> 518 click -> ..518 페이지 크롤링 완료
# 현재 518 -> 519 click -> ..519 페이지 크롤링 완료
# 현재 519 -> 520 click -> ..520 페이지 크롤링 완료
# 현재 520 -> 다음 click -> ..521 페이지 크롤링 완료
# 현재 521 -> 522 click -> ..522 페이지 크롤링 완료
# 현재 522 -> 523 click -> ..523 페이지 크롤링 완료
# 현재 523 -> 524 click -> ..524 페이지 크롤링 완료
# 현재 524 -> 525 click -> ..525 페이지 크롤링 완료
# 현재 525 -> 526 click -> ..526 페이지 크롤링 완료
# 현재 526 -> 527 click -> ..527 페이지 크롤링 완료
# 현재 527 -> 528 click -> ..528 페이지 크롤링 완료
# 현재 528 -> 529 click -> ..529 페이지 크롤링 완료
# 현재 529 -> 530 click -> ..530 페이지 크롤링 완료
# 현재 530 -> 다음 click -> ..531 페이지 크롤링 완료
# 현재 531 -> 532 click -> ..532 페이지 크롤링 완료
# 현재 532 -> 533 click -> ..533 페이지 크롤링 완료
# 현재 533 -> 534 click -> ..534 페이지 크롤링 완료
# 현재 534 -> 535 click -> ..535 페이지 크롤링 완료
# 현재 535 -> 536 click -> ..536 페이지 크롤링 완료
# 현재 536 -> 537 click -> ..537 페이지 크롤링 완료
# 현재 537 -> 538 click -> ..538 페이지 크롤링 완료
# 현재 538 -> 539 click -> ..539 페이지 크롤링 완료
# 현재 539 -> 540 click -> ..540 페이지 크롤링 완료
# 현재 540 -> 다음 click -> ..541 페이지 크롤링 완료
# 현재 541 -> 542 click -> ..542 페이지 크롤링 완료
# 현재 542 -> 543 click -> ..543 페이지 크롤링 완료
# 현재 543 -> 544 click -> ..544 페이지 크롤링 완료
# 현재 544 -> 545 click -> ..545 페이지 크롤링 완료
# 현재 545 -> 546 click -> ..546 페이지 크롤링 완료
# 현재 546 -> 547 click -> ..547 페이지 크롤링 완료
# 현재 547 -> 548 click -> ..548 페이지 크롤링 완료
# 현재 548 -> 549 click -> ..549 페이지 크롤링 완료
# 현재 549 -> 550 click -> ..550 페이지 크롤링 완료
# 현재 550 -> 다음 click -> ..551 페이지 크롤링 완료
# 현재 551 -> 552 click -> ..552 페이지 크롤링 완료
# 현재 552 -> 553 click -> ..553 페이지 크롤링 완료
# 현재 553 -> 554 click -> ..554 페이지 크롤링 완료
# 현재 554 -> 555 click -> ..555 페이지 크롤링 완료
# 현재 555 -> 556 click -> ..556 페이지 크롤링 완료
# 현재 556 -> 557 click -> ..557 페이지 크롤링 완료
# 현재 557 -> 558 click -> ..558 페이지 크롤링 완료
# 현재 558 -> 559 click -> ..559 페이지 크롤링 완료
# 현재 559 -> 560 click -> ..560 페이지 크롤링 완료
# 현재 560 -> 다음 click -> ..561 페이지 크롤링 완료
# 현재 561 -> 562 click -> ..562 페이지 크롤링 완료
# 현재 562 -> 563 click -> ..563 페이지 크롤링 완료
# 현재 563 -> 564 click -> ..564 페이지 크롤링 완료
# 현재 564 -> 565 click -> ..565 페이지 크롤링 완료
# 현재 565 -> 566 click -> ..566 페이지 크롤링 완료
# 현재 566 -> 567 click -> ..567 페이지 크롤링 완료
# 현재 567 -> 568 click -> ..568 페이지 크롤링 완료
# 현재 568 -> 569 click -> ..569 페이지 크롤링 완료
# 현재 569 -> 570 click -> ..570 페이지 크롤링 완료
# 현재 570 -> 다음 click -> ..571 페이지 크롤링 완료
# 현재 571 -> 572 click -> ..572 페이지 크롤링 완료
# 현재 572 -> 573 click -> ..573 페이지 크롤링 완료
# 현재 573 -> 574 click -> ..574 페이지 크롤링 완료
# 현재 574 -> 575 click -> ..575 페이지 크롤링 완료
# 현재 575 -> 576 click -> ..576 페이지 크롤링 완료
# 현재 576 -> 577 click -> ..577 페이지 크롤링 완료
# 현재 577 -> 578 click -> ..578 페이지 크롤링 완료
# 현재 578 -> 579 click -> ..579 페이지 크롤링 완료
# 현재 579 -> 580 click -> ..580 페이지 크롤링 완료
# 현재 580 -> 다음 click -> ..581 페이지 크롤링 완료
# 현재 581 -> 582 click -> ..582 페이지 크롤링 완료
# 현재 582 -> 583 click -> ..583 페이지 크롤링 완료
# 현재 583 -> 584 click -> ..584 페이지 크롤링 완료
# 현재 584 -> 585 click -> ..585 페이지 크롤링 완료
# 현재 585 -> 586 click -> ..586 페이지 크롤링 완료
# 현재 586 -> 587 click -> ..587 페이지 크롤링 완료
# 현재 587 -> 588 click -> ..588 페이지 크롤링 완료
# 현재 588 -> 589 click -> ..589 페이지 크롤링 완료
# 현재 589 -> 590 click -> ..590 페이지 크롤링 완료
# 현재 590 -> 다음 click -> ..591 페이지 크롤링 완료
# 현재 591 -> 592 click -> ..592 페이지 크롤링 완료
# 현재 592 -> 593 click -> ..593 페이지 크롤링 완료
# 현재 593 -> 594 click -> ..594 페이지 크롤링 완료
# 현재 594 -> 595 click -> ..595 페이지 크롤링 완료
# 현재 595 -> 596 click -> ..596 페이지 크롤링 완료
# 현재 596 -> 597 click -> ..597 페이지 크롤링 완료
# 현재 597 -> 598 click -> ..598 페이지 크롤링 완료
# 현재 598 -> 599 click -> ..599 페이지 크롤링 완료
# 현재 599 -> 600 click -> ..600 페이지 크롤링 완료
# 검색 옵션 설정....검색 완료
# 데이터 추출 준비중...완료
# 시작 페이지로 이동........................................................................................................................601 위치 -> 601 페이지 크롤링 완료
# 현재 601 -> 602 click -> ..602 페이지 크롤링 완료
# 현재 602 -> 603 click -> ..603 페이지 크롤링 완료
# 현재 603 -> 604 click -> ..604 페이지 크롤링 완료
# 현재 604 -> 605 click -> ..605 페이지 크롤링 완료
# 현재 605 -> 606 click -> ..606 페이지 크롤링 완료
# 현재 606 -> 607 click -> ..607 페이지 크롤링 완료
# 현재 607 -> 608 click -> ..608 페이지 크롤링 완료
# 현재 608 -> 609 click -> ..609 페이지 크롤링 완료
# 현재 609 -> 610 click -> ..610 페이지 크롤링 완료
# 현재 610 -> 다음 click -> ..611 페이지 크롤링 완료
# 현재 611 -> 612 click -> ..612 페이지 크롤링 완료
# 현재 612 -> 613 click -> ..613 페이지 크롤링 완료
# 현재 613 -> 614 click -> ..614 페이지 크롤링 완료
# 현재 614 -> 615 click -> ..615 페이지 크롤링 완료
# 현재 615 -> 616 click -> ..616 페이지 크롤링 완료
# 현재 616 -> 617 click -> ..617 페이지 크롤링 완료
# 현재 617 -> 618 click -> ..618 페이지 크롤링 완료
# 현재 618 -> 619 click -> ..619 페이지 크롤링 완료
# 현재 619 -> 620 click -> ..620 페이지 크롤링 완료
# 현재 620 -> 다음 click -> ..621 페이지 크롤링 완료
# 현재 621 -> 622 click -> ..622 페이지 크롤링 완료
# 현재 622 -> 623 click -> ..623 페이지 크롤링 완료
# 현재 623 -> 624 click -> ..624 페이지 크롤링 완료
# 현재 624 -> 625 click -> ..625 페이지 크롤링 완료
# 현재 625 -> 626 click -> ..626 페이지 크롤링 완료
# 현재 626 -> 627 click -> ..627 페이지 크롤링 완료
# 현재 627 -> 628 click -> ..628 페이지 크롤링 완료
# 현재 628 -> 629 click -> ..629 페이지 크롤링 완료
# 현재 629 -> 630 click -> ..630 페이지 크롤링 완료
# 현재 630 -> 다음 click -> ..631 페이지 크롤링 완료
# 현재 631 -> 632 click -> ..632 페이지 크롤링 완료
# 현재 632 -> 633 click -> ..633 페이지 크롤링 완료
# 현재 633 -> 634 click -> ..634 페이지 크롤링 완료
# 현재 634 -> 635 click -> ..635 페이지 크롤링 완료
# 현재 635 -> 636 click -> ..636 페이지 크롤링 완료
# 현재 636 -> 637 click -> ..637 페이지 크롤링 완료
# 현재 637 -> 638 click -> ..638 페이지 크롤링 완료
# 현재 638 -> 639 click -> ..639 페이지 크롤링 완료
# 현재 639 -> 640 click -> ..640 페이지 크롤링 완료
# 현재 640 -> 다음 click -> ..641 페이지 크롤링 완료
# 현재 641 -> 642 click -> ..642 페이지 크롤링 완료
# 현재 642 -> 643 click -> ..643 페이지 크롤링 완료
# 현재 643 -> 644 click -> ..644 페이지 크롤링 완료
# 현재 644 -> 645 click -> ..645 페이지 크롤링 완료
# 현재 645 -> 646 click -> ..646 페이지 크롤링 완료
# 현재 646 -> 647 click -> ..647 페이지 크롤링 완료
# 현재 647 -> 648 click -> ..648 페이지 크롤링 완료
# 현재 648 -> 649 click -> ..649 페이지 크롤링 완료
# 현재 649 -> 650 click -> ..650 페이지 크롤링 완료
# 현재 650 -> 다음 click -> ..651 페이지 크롤링 완료
# 현재 651 -> 652 click -> ..652 페이지 크롤링 완료
# 현재 652 -> 653 click -> ..653 페이지 크롤링 완료
# 현재 653 -> 654 click -> ..654 페이지 크롤링 완료
# 현재 654 -> 655 click -> ..655 페이지 크롤링 완료
# 현재 655 -> 656 click -> ..656 페이지 크롤링 완료
# 현재 656 -> 657 click -> ..657 페이지 크롤링 완료
# 현재 657 -> 658 click -> ..658 페이지 크롤링 완료
# 현재 658 -> 659 click -> ..659 페이지 크롤링 완료
# 현재 659 -> 660 click -> ..660 페이지 크롤링 완료
# 현재 660 -> 다음 click -> ..661 페이지 크롤링 완료
# 현재 661 -> 662 click -> ..662 페이지 크롤링 완료
# 현재 662 -> 663 click -> ..663 페이지 크롤링 완료
# 현재 663 -> 664 click -> ..664 페이지 크롤링 완료
# 현재 664 -> 665 click -> ..665 페이지 크롤링 완료
# 현재 665 -> 666 click -> ..666 페이지 크롤링 완료
# 현재 666 -> 667 click -> ..667 페이지 크롤링 완료
# 현재 667 -> 668 click -> ..668 페이지 크롤링 완료
# 현재 668 -> 669 click -> ..669 페이지 크롤링 완료
# 현재 669 -> 670 click -> ..670 페이지 크롤링 완료
# 현재 670 -> 다음 click -> ..671 페이지 크롤링 완료
# 현재 671 -> 672 click -> ..672 페이지 크롤링 완료
# 현재 672 -> 673 click -> ..673 페이지 크롤링 완료
# 현재 673 -> 674 click -> ..674 페이지 크롤링 완료
# 현재 674 -> 675 click -> ..675 페이지 크롤링 완료
# 현재 675 -> 676 click -> ..676 페이지 크롤링 완료
# 현재 676 -> 677 click -> ..677 페이지 크롤링 완료
# 현재 677 -> 678 click -> ..678 페이지 크롤링 완료
# 현재 678 -> 679 click -> ..679 페이지 크롤링 완료
# 현재 679 -> 680 click -> ..680 페이지 크롤링 완료
# 현재 680 -> 다음 click -> ..681 페이지 크롤링 완료
# 현재 681 -> 682 click -> ..682 페이지 크롤링 완료
# 현재 682 -> 683 click -> ..683 페이지 크롤링 완료
# 현재 683 -> 684 click -> ..684 페이지 크롤링 완료
# 현재 684 -> 685 click -> ..685 페이지 크롤링 완료
# 현재 685 -> 686 click -> ..686 페이지 크롤링 완료
# 현재 686 -> 687 click -> ..687 페이지 크롤링 완료
# 현재 687 -> 688 click -> ..688 페이지 크롤링 완료
# 현재 688 -> 689 click -> ..689 페이지 크롤링 완료
# 현재 689 -> 690 click -> ..690 페이지 크롤링 완료
# 현재 690 -> 다음 click -> ..691 페이지 크롤링 완료
# 현재 691 -> 692 click -> ..692 페이지 크롤링 완료
# 현재 692 -> 693 click -> ..693 페이지 크롤링 완료
# 현재 693 -> 694 click -> ..694 페이지 크롤링 완료
# 현재 694 -> 695 click -> ..695 페이지 크롤링 완료
# 현재 695 -> 696 click -> ..696 페이지 크롤링 완료
# 현재 696 -> 697 click -> ..697 페이지 크롤링 완료
# 현재 697 -> 698 click -> ..698 페이지 크롤링 완료
# 현재 698 -> 699 click -> ..699 페이지 크롤링 완료
# 현재 699 -> 700 click -> ..700 페이지 크롤링 완료
# 현재 700 -> 다음 click -> ..701 페이지 크롤링 완료
# 현재 701 -> 702 click -> ..702 페이지 크롤링 완료
# 현재 702 -> 703 click -> ..703 페이지 크롤링 완료
# 현재 703 -> 704 click -> ..704 페이지 크롤링 완료
# 현재 704 -> 705 click -> ..705 페이지 크롤링 완료
# 현재 705 -> 706 click -> ..706 페이지 크롤링 완료
# 현재 706 -> 707 click -> ..707 페이지 크롤링 완료
# 현재 707 -> 708 click -> ..708 페이지 크롤링 완료
# 현재 708 -> 709 click -> ..709 페이지 크롤링 완료
# 현재 709 -> 710 click -> ..710 페이지 크롤링 완료
# 현재 710 -> 다음 click -> ..711 페이지 크롤링 완료
# 현재 711 -> 712 click -> ..712 페이지 크롤링 완료
# 현재 712 -> 713 click -> ..713 페이지 크롤링 완료
# 현재 713 -> 714 click -> ..714 페이지 크롤링 완료
# 현재 714 -> 715 click -> ..715 페이지 크롤링 완료
# 현재 715 -> 716 click -> ..716 페이지 크롤링 완료
# 현재 716 -> 717 click -> ..717 페이지 크롤링 완료
# 현재 717 -> 718 click -> ..718 페이지 크롤링 완료
# 현재 718 -> 719 click -> ..719 페이지 크롤링 완료
# 현재 719 -> 720 click -> ..720 페이지 크롤링 완료
# 현재 720 -> 다음 click -> ..721 페이지 크롤링 완료
# 현재 721 -> 722 click -> ..722 페이지 크롤링 완료
# 현재 722 -> 723 click -> ..723 페이지 크롤링 완료
# 현재 723 -> 724 click -> ..724 페이지 크롤링 완료
# 현재 724 -> 725 click -> ..725 페이지 크롤링 완료
# 현재 725 -> 726 click -> ..726 페이지 크롤링 완료
# 현재 726 -> 727 click -> ..727 페이지 크롤링 완료
# 현재 727 -> 728 click -> ..728 페이지 크롤링 완료
# 현재 728 -> 729 click -> ..729 페이지 크롤링 완료
# 현재 729 -> 730 click -> ..730 페이지 크롤링 완료
# 현재 730 -> 다음 click -> ..731 페이지 크롤링 완료
# 현재 731 -> 732 click -> ..732 페이지 크롤링 완료
# 현재 732 -> 733 click -> ..733 페이지 크롤링 완료
# 현재 733 -> 734 click -> ..734 페이지 크롤링 완료
# 현재 734 -> 735 click -> ..735 페이지 크롤링 완료
# 현재 735 -> 736 click -> ..736 페이지 크롤링 완료
# 현재 736 -> 737 click -> ..737 페이지 크롤링 완료
# 현재 737 -> 738 click -> ..738 페이지 크롤링 완료
# 현재 738 -> 739 click -> ..739 페이지 크롤링 완료
# 현재 739 -> 740 click -> ..740 페이지 크롤링 완료
# 현재 740 -> 다음 click -> ..741 페이지 크롤링 완료
# 현재 741 -> 742 click -> ..742 페이지 크롤링 완료
# 현재 742 -> 743 click -> ..743 페이지 크롤링 완료
# 현재 743 -> 744 click -> ..744 페이지 크롤링 완료
# 현재 744 -> 745 click -> ..745 페이지 크롤링 완료
# 현재 745 -> 746 click -> ..746 페이지 크롤링 완료
# 현재 746 -> 747 click -> ..747 페이지 크롤링 완료
# 현재 747 -> 748 click -> ..748 페이지 크롤링 완료
# 현재 748 -> 749 click -> ..749 페이지 크롤링 완료
# 현재 749 -> 750 click -> ..750 페이지 크롤링 완료
# 현재 750 -> 다음 click -> ..751 페이지 크롤링 완료
# 현재 751 -> 752 click -> ..752 페이지 크롤링 완료
# 현재 752 -> 753 click -> ..753 페이지 크롤링 완료
# 현재 753 -> 754 click -> ..754 페이지 크롤링 완료
# 현재 754 -> 755 click -> ..755 페이지 크롤링 완료
# 현재 755 -> 756 click -> ..756 페이지 크롤링 완료
# 현재 756 -> 757 click -> ..757 페이지 크롤링 완료
# 현재 757 -> 758 click -> ..758 페이지 크롤링 완료
# 현재 758 -> 759 click -> ..759 페이지 크롤링 완료
# 현재 759 -> 760 click -> ..760 페이지 크롤링 완료
# 현재 760 -> 다음 click -> ..761 페이지 크롤링 완료
# 현재 761 -> 762 click -> ..762 페이지 크롤링 완료
# 현재 762 -> 763 click -> ..763 페이지 크롤링 완료
# 현재 763 -> 764 click -> ..764 페이지 크롤링 완료
# 현재 764 -> 765 click -> ..765 페이지 크롤링 완료
# 현재 765 -> 766 click -> ..766 페이지 크롤링 완료
# 현재 766 -> 767 click -> ..767 페이지 크롤링 완료
# 현재 767 -> 768 click -> ..768 페이지 크롤링 완료
# 현재 768 -> 769 click -> ..769 페이지 크롤링 완료
# 현재 769 -> 770 click -> ..770 페이지 크롤링 완료
# 현재 770 -> 다음 click -> ..771 페이지 크롤링 완료
# 현재 771 -> 772 click -> ..772 페이지 크롤링 완료
# 현재 772 -> 773 click -> ..773 페이지 크롤링 완료
# 현재 773 -> 774 click -> ..774 페이지 크롤링 완료
# 현재 774 -> 775 click -> ..775 페이지 크롤링 완료
# 현재 775 -> 776 click -> ..776 페이지 크롤링 완료
# 현재 776 -> 777 click -> ..777 페이지 크롤링 완료
# 현재 777 -> 778 click -> ..778 페이지 크롤링 완료
# 현재 778 -> 779 click -> ..779 페이지 크롤링 완료
# 현재 779 -> 780 click -> ..780 페이지 크롤링 완료
# 현재 780 -> 다음 click -> ..781 페이지 크롤링 완료
# 현재 781 -> 782 click -> ..782 페이지 크롤링 완료
# 현재 782 -> 783 click -> ..783 페이지 크롤링 완료
# 현재 783 -> 784 click -> ..784 페이지 크롤링 완료
# 현재 784 -> 785 click -> ..785 페이지 크롤링 완료
# 현재 785 -> 786 click -> ..786 페이지 크롤링 완료
# 현재 786 -> 787 click -> ..787 페이지 크롤링 완료
# 현재 787 -> 788 click -> ..788 페이지 크롤링 완료
# 현재 788 -> 789 click -> ..789 페이지 크롤링 완료
# 현재 789 -> 790 click -> ..790 페이지 크롤링 완료
# 현재 790 -> 다음 click -> ..791 페이지 크롤링 완료
# 현재 791 -> 792 click -> ..792 페이지 크롤링 완료
# 현재 792 -> 793 click -> ..793 페이지 크롤링 완료
# 현재 793 -> 794 click -> ..794 페이지 크롤링 완료
# 현재 794 -> 795 click -> ..795 페이지 크롤링 완료
# 현재 795 -> 796 click -> ..796 페이지 크롤링 완료
# 현재 796 -> 797 click -> ..797 페이지 크롤링 완료
# 현재 797 -> 798 click -> ..798 페이지 크롤링 완료
# 현재 798 -> 799 click -> ..799 페이지 크롤링 완료
# 현재 799 -> 800 click -> ..800 페이지 크롤링 완료
# 검색 옵션 설정....검색 완료
# 데이터 추출 준비중...완료
# 시작 페이지로 이동................................................................................................................................................................801 위치 -> 801 페이지 크롤링 완료
# 현재 801 -> 802 click -> ..802 페이지 크롤링 완료
# 현재 802 -> 803 click -> ..803 페이지 크롤링 완료
# 현재 803 -> 804 click -> ..804 페이지 크롤링 완료
# 현재 804 -> 805 click -> ..805 페이지 크롤링 완료
# 현재 805 -> 806 click -> ..806 페이지 크롤링 완료
# 현재 806 -> 807 click -> ..807 페이지 크롤링 완료
# 현재 807 -> 808 click -> ..808 페이지 크롤링 완료
# 현재 808 -> 809 click -> ..809 페이지 크롤링 완료
# 현재 809 -> 810 click -> ..810 페이지 크롤링 완료
# 현재 810 -> 다음 click -> ..811 페이지 크롤링 완료
# 현재 811 -> 812 click -> ..812 페이지 크롤링 완료
# 현재 812 -> 813 click -> ..813 페이지 크롤링 완료
# 현재 813 -> 814 click -> ..814 페이지 크롤링 완료
# 현재 814 -> 815 click -> ..815 페이지 크롤링 완료
# 현재 815 -> 816 click -> ..816 페이지 크롤링 완료
# 현재 816 -> 817 click -> ..817 페이지 크롤링 완료
# 현재 817 -> 818 click -> ..818 페이지 크롤링 완료
# 현재 818 -> 819 click -> ..819 페이지 크롤링 완료
# 현재 819 -> 820 click -> ..820 페이지 크롤링 완료
# 현재 820 -> 다음 click -> ..821 페이지 크롤링 완료
# 현재 821 -> 822 click -> ..822 페이지 크롤링 완료
# 현재 822 -> 823 click -> ..823 페이지 크롤링 완료
# 현재 823 -> 824 click -> ..824 페이지 크롤링 완료
# 현재 824 -> 825 click -> ..825 페이지 크롤링 완료
# 현재 825 -> 826 click -> ..826 페이지 크롤링 완료
# 현재 826 -> 827 click -> ..827 페이지 크롤링 완료
# 현재 827 -> 828 click -> ..828 페이지 크롤링 완료
# 현재 828 -> 829 click -> ..829 페이지 크롤링 완료
# 현재 829 -> 830 click -> ..830 페이지 크롤링 완료
# 현재 830 -> 다음 click -> ..831 페이지 크롤링 완료
# 현재 831 -> 832 click -> ..832 페이지 크롤링 완료
# 현재 832 -> 833 click -> ..833 페이지 크롤링 완료
# 현재 833 -> 834 click -> ..834 페이지 크롤링 완료
# 현재 834 -> 835 click -> ..835 페이지 크롤링 완료
# 현재 835 -> 836 click -> ..836 페이지 크롤링 완료
# 현재 836 -> 837 click -> ..837 페이지 크롤링 완료
# 현재 837 -> 838 click -> ..838 페이지 크롤링 완료
# 현재 838 -> 839 click -> ..839 페이지 크롤링 완료
# 현재 839 -> 840 click -> ..840 페이지 크롤링 완료
# 현재 840 -> 다음 click -> ..841 페이지 크롤링 완료
# 현재 841 -> 842 click -> ..842 페이지 크롤링 완료
# 현재 842 -> 843 click -> ..843 페이지 크롤링 완료
# 현재 843 -> 844 click -> ..844 페이지 크롤링 완료
# 현재 844 -> 845 click -> ..845 페이지 크롤링 완료
# 현재 845 -> 846 click -> ..846 페이지 크롤링 완료
# 현재 846 -> 847 click -> ..847 페이지 크롤링 완료
# 현재 847 -> 848 click -> ..848 페이지 크롤링 완료
# 현재 848 -> 849 click -> ..849 페이지 크롤링 완료
# 현재 849 -> 850 click -> ..850 페이지 크롤링 완료
# 현재 850 -> 다음 click -> ..851 페이지 크롤링 완료
# 현재 851 -> 852 click -> ..852 페이지 크롤링 완료
# 현재 852 -> 853 click -> ..853 페이지 크롤링 완료
# 현재 853 -> 854 click -> ..854 페이지 크롤링 완료
# 현재 854 -> 855 click -> ..855 페이지 크롤링 완료
# 현재 855 -> 856 click -> ..856 페이지 크롤링 완료
# 현재 856 -> 857 click -> ..857 페이지 크롤링 완료
# 현재 857 -> 858 click -> ..858 페이지 크롤링 완료
# 현재 858 -> 859 click -> ..859 페이지 크롤링 완료
# 현재 859 -> 860 click -> ..860 페이지 크롤링 완료
# 현재 860 -> 다음 click -> ..861 페이지 크롤링 완료
# 현재 861 -> 862 click -> ..862 페이지 크롤링 완료
# 현재 862 -> 863 click -> ..863 페이지 크롤링 완료
# 현재 863 -> 864 click -> ..864 페이지 크롤링 완료
# 현재 864 -> 865 click -> ..865 페이지 크롤링 완료
# 현재 865 -> 866 click -> ..866 페이지 크롤링 완료
# 현재 866 -> 867 click -> ..867 페이지 크롤링 완료
# 현재 867 -> 868 click -> ..868 페이지 크롤링 완료
# 현재 868 -> 869 click -> ..869 페이지 크롤링 완료
# 현재 869 -> 870 click -> ..870 페이지 크롤링 완료
# 현재 870 -> 다음 click -> ..871 페이지 크롤링 완료
# 현재 871 -> 872 click -> ..872 페이지 크롤링 완료
# 현재 872 -> 873 click -> ..873 페이지 크롤링 완료
# 현재 873 -> 874 click -> ..874 페이지 크롤링 완료
# 현재 874 -> 875 click -> ..875 페이지 크롤링 완료
# 현재 875 -> 876 click -> ..876 페이지 크롤링 완료
# 현재 876 -> 877 click -> ..877 페이지 크롤링 완료
# 현재 877 -> 878 click -> ..878 페이지 크롤링 완료
# 현재 878 -> 879 click -> ..879 페이지 크롤링 완료
# 현재 879 -> 880 click -> ..880 페이지 크롤링 완료
# 현재 880 -> 다음 click -> ..881 페이지 크롤링 완료
# 현재 881 -> 882 click -> ..882 페이지 크롤링 완료
# 현재 882 -> 883 click -> ..883 페이지 크롤링 완료
# 현재 883 -> 884 click -> ..884 페이지 크롤링 완료
# 현재 884 -> 885 click -> ..885 페이지 크롤링 완료
# 현재 885 -> 886 click -> ..886 페이지 크롤링 완료
# 현재 886 -> 887 click -> ..887 페이지 크롤링 완료
# 현재 887 -> 888 click -> ..888 페이지 크롤링 완료
# 현재 888 -> 889 click -> ..889 페이지 크롤링 완료
# 현재 889 -> 890 click -> ..890 페이지 크롤링 완료
# 현재 890 -> 다음 click -> ..891 페이지 크롤링 완료
# 현재 891 -> 892 click -> ..892 페이지 크롤링 완료
# 현재 892 -> 893 click -> ..893 페이지 크롤링 완료
# 현재 893 -> 894 click -> ..894 페이지 크롤링 완료
# 현재 894 -> 895 click -> ..895 페이지 크롤링 완료
# 현재 895 -> 896 click -> ..896 페이지 크롤링 완료
# 현재 896 -> 897 click -> ..897 페이지 크롤링 완료
# 현재 897 -> 898 click -> ..898 페이지 크롤링 완료
# 현재 898 -> 899 click -> ..899 페이지 크롤링 완료
# 현재 899 -> 900 click -> ..900 페이지 크롤링 완료
# 현재 900 -> 다음 click -> ..901 페이지 크롤링 완료
# 현재 901 -> 902 click -> ..902 페이지 크롤링 완료
# 현재 902 -> 903 click -> ..903 페이지 크롤링 완료
# 현재 903 -> 904 click -> ..904 페이지 크롤링 완료
# 현재 904 -> 905 click -> ..905 페이지 크롤링 완료
# 현재 905 -> 906 click -> ..906 페이지 크롤링 완료
# 현재 906 -> 907 click -> ..907 페이지 크롤링 완료
# 현재 907 -> 908 click -> ..908 페이지 크롤링 완료
# 현재 908 -> 909 click -> ..909 페이지 크롤링 완료
# 현재 909 -> 910 click -> ..910 페이지 크롤링 완료
# 현재 910 -> 다음 click -> ..911 페이지 크롤링 완료
# 현재 911 -> 912 click -> ..912 페이지 크롤링 완료
# 현재 912 -> 913 click -> ..913 페이지 크롤링 완료
# 현재 913 -> 914 click -> ..914 페이지 크롤링 완료
# 현재 914 -> 915 click -> ..915 페이지 크롤링 완료
# 현재 915 -> 916 click -> ..916 페이지 크롤링 완료
# 현재 916 -> 917 click -> ..917 페이지 크롤링 완료
# 현재 917 -> 918 click -> ..918 페이지 크롤링 완료
# 현재 918 -> 919 click -> ..919 페이지 크롤링 완료
# 현재 919 -> 920 click -> ..920 페이지 크롤링 완료
# 현재 920 -> 다음 click -> ..921 페이지 크롤링 완료
# 현재 921 -> 922 click -> ..922 페이지 크롤링 완료
# 현재 922 -> 923 click -> ..923 페이지 크롤링 완료
# 현재 923 -> 924 click -> ..924 페이지 크롤링 완료
# 현재 924 -> 925 click -> ..925 페이지 크롤링 완료
# 현재 925 -> 926 click -> ..926 페이지 크롤링 완료
# 현재 926 -> 927 click -> ..927 페이지 크롤링 완료
# 현재 927 -> 928 click -> ..928 페이지 크롤링 완료
# 현재 928 -> 929 click -> ..929 페이지 크롤링 완료
# 현재 929 -> 930 click -> ..930 페이지 크롤링 완료
# 현재 930 -> 다음 click -> ..931 페이지 크롤링 완료
# 현재 931 -> 932 click -> ..932 페이지 크롤링 완료
# 현재 932 -> 933 click -> ..933 페이지 크롤링 완료
# 현재 933 -> 934 click -> ..934 페이지 크롤링 완료
# 현재 934 -> 935 click -> ..935 페이지 크롤링 완료
# 현재 935 -> 936 click -> ..936 페이지 크롤링 완료
# 현재 936 -> 937 click -> ..937 페이지 크롤링 완료
# 현재 937 -> 938 click -> ..938 페이지 크롤링 완료
# 현재 938 -> 939 click -> ..939 페이지 크롤링 완료
# 현재 939 -> 940 click -> ..940 페이지 크롤링 완료
# 현재 940 -> 다음 click -> ..941 페이지 크롤링 완료
# 현재 941 -> 942 click -> ..942 페이지 크롤링 완료
# 현재 942 -> 943 click -> ..943 페이지 크롤링 완료
# 현재 943 -> 944 click -> ..944 페이지 크롤링 완료
# 현재 944 -> 945 click -> ..945 페이지 크롤링 완료
# 현재 945 -> 946 click -> ..946 페이지 크롤링 완료
# 현재 946 -> 947 click -> ..947 페이지 크롤링 완료
# 현재 947 -> 948 click -> ..948 페이지 크롤링 완료
# 현재 948 -> 949 click -> ..949 페이지 크롤링 완료
# 현재 949 -> 950 click -> ..950 페이지 크롤링 완료
# 현재 950 -> 다음 click -> ..951 페이지 크롤링 완료
# 현재 951 -> 952 click -> ..952 페이지 크롤링 완료
# 현재 952 -> 953 click -> ..953 페이지 크롤링 완료
# 현재 953 -> 954 click -> ..954 페이지 크롤링 완료
# 현재 954 -> 955 click -> ..955 페이지 크롤링 완료
# 현재 955 -> 956 click -> ..956 페이지 크롤링 완료
# 현재 956 -> 957 click -> ..957 페이지 크롤링 완료
# 현재 957 -> 958 click -> ..958 페이지 크롤링 완료
# 현재 958 -> 959 click -> ..959 페이지 크롤링 완료
# 현재 959 -> 960 click -> ..960 페이지 크롤링 완료
# 현재 960 -> 다음 click -> ..961 페이지 크롤링 완료
# 현재 961 -> 962 click -> ..962 페이지 크롤링 완료
# 현재 962 -> 963 click -> ..963 페이지 크롤링 완료
# 현재 963 -> 964 click -> ..964 페이지 크롤링 완료
# 현재 964 -> 965 click -> ..965 페이지 크롤링 완료
# 현재 965 -> 966 click -> ..966 페이지 크롤링 완료
# 현재 966 -> 967 click -> ..967 페이지 크롤링 완료
# 현재 967 -> 968 click -> ..968 페이지 크롤링 완료
# 현재 968 -> 969 click -> ..969 페이지 크롤링 완료
# 현재 969 -> 970 click -> ..970 페이지 크롤링 완료
# 현재 970 -> 다음 click -> ..971 페이지 크롤링 완료
# 현재 971 -> 972 click -> ..972 페이지 크롤링 완료
# 현재 972 -> 973 click -> ..973 페이지 크롤링 완료
# 현재 973 -> 974 click -> ..974 페이지 크롤링 완료
# 현재 974 -> 975 click -> ..975 페이지 크롤링 완료
# 현재 975 -> 976 click -> ..976 페이지 크롤링 완료
# 현재 976 -> 977 click -> ..977 페이지 크롤링 완료
# 현재 977 -> 978 click -> ..978 페이지 크롤링 완료
# 현재 978 -> 979 click -> ..979 페이지 크롤링 완료
# 현재 979 -> 980 click -> ..980 페이지 크롤링 완료
# 현재 980 -> 다음 click -> ..981 페이지 크롤링 완료
# 현재 981 -> 982 click -> ..982 페이지 크롤링 완료
# 현재 982 -> 983 click -> ..983 페이지 크롤링 완료
# 현재 983 -> 984 click -> ..984 페이지 크롤링 완료
# 현재 984 -> 985 click -> ..985 페이지 크롤링 완료
# 현재 985 -> 986 click -> ..986 페이지 크롤링 완료
# 현재 986 -> 987 click -> ..987 페이지 크롤링 완료
# 현재 987 -> 988 click -> ..988 페이지 크롤링 완료
# 현재 988 -> 989 click -> ..989 페이지 크롤링 완료
# 현재 989 -> 990 click -> ..990 페이지 크롤링 완료
# 현재 990 -> 다음 click -> ..991 페이지 크롤링 완료
# 현재 991 -> 992 click -> ..992 페이지 크롤링 완료
# 현재 992 -> 993 click -> ..993 페이지 크롤링 완료
# 현재 993 -> 994 click -> ..994 페이지 크롤링 완료
# 현재 994 -> 995 click -> ..995 페이지 크롤링 완료
# 현재 995 -> 996 click -> ..996 페이지 크롤링 완료
# 현재 996 -> 997 click -> ..997 페이지 크롤링 완료
# 현재 997 -> 998 click -> ..998 페이지 크롤링 완료
# 현재 998 -> 999 click -> ..999 페이지 크롤링 완료
# 현재 999 -> 1000 click -> ..1000 페이지 크롤링 완료
# 검색 옵션 설정....검색 완료
# 데이터 추출 준비중...완료
# 시작 페이지로 이동........................................................................................................................................................................................................1001 위치 -> 1001 페이지 크롤링 완료
# 현재 1001 -> 1002 click -> ..1002 페이지 크롤링 완료
# 현재 1002 -> 1003 click -> ..1003 페이지 크롤링 완료
# 현재 1003 -> 1004 click -> ..1004 페이지 크롤링 완료
# 현재 1004 -> 1005 click -> ..1005 페이지 크롤링 완료
# 현재 1005 -> 1006 click -> ..1006 페이지 크롤링 완료
# 현재 1006 -> 1007 click -> ..1007 페이지 크롤링 완료
# 현재 1007 -> 1008 click -> ..1008 페이지 크롤링 완료
# 현재 1008 -> 1009 click -> ..1009 페이지 크롤링 완료
# 현재 1009 -> 1010 click -> ..1010 페이지 크롤링 완료
# 현재 1010 -> 다음 click -> ..1011 페이지 크롤링 완료
# 현재 1011 -> 1012 click -> ..1012 페이지 크롤링 완료
# 현재 1012 -> 1013 click -> ..1013 페이지 크롤링 완료
# 현재 1013 -> 1014 click -> ..1014 페이지 크롤링 완료
# 현재 1014 -> 1015 click -> ..1015 페이지 크롤링 완료
# 현재 1015 -> 1016 click -> ..1016 페이지 크롤링 완료
# 현재 1016 -> 1017 click -> ..1017 페이지 크롤링 완료
# 현재 1017 -> 1018 click -> ..1018 페이지 크롤링 완료
# 현재 1018 -> 1019 click -> ..1019 페이지 크롤링 완료
# 현재 1019 -> 1020 click -> ..1020 페이지 크롤링 완료
# 현재 1020 -> 다음 click -> ..1021 페이지 크롤링 완료
# 현재 1021 -> 1022 click -> ..1022 페이지 크롤링 완료
# 현재 1022 -> 1023 click -> ..1023 페이지 크롤링 완료
# 현재 1023 -> 1024 click -> ..1024 페이지 크롤링 완료
# 현재 1024 -> 1025 click -> ..1025 페이지 크롤링 완료
# 현재 1025 -> 1026 click -> ..1026 페이지 크롤링 완료
# 현재 1026 -> 1027 click -> ..1027 페이지 크롤링 완료
# 현재 1027 -> 1028 click -> ..1028 페이지 크롤링 완료
# 현재 1028 -> 1029 click -> ..1029 페이지 크롤링 완료
# 현재 1029 -> 1030 click -> ..1030 페이지 크롤링 완료
# 현재 1030 -> 다음 click -> ..1031 페이지 크롤링 완료
# 현재 1031 -> 1032 click -> ..1032 페이지 크롤링 완료
# 현재 1032 -> 1033 click -> ..1033 페이지 크롤링 완료
# 현재 1033 -> 1034 click -> ..1034 페이지 크롤링 완료
# 현재 1034 -> 1035 click -> ..1035 페이지 크롤링 완료
# 현재 1035 -> 1036 click -> ..1036 페이지 크롤링 완료
# 현재 1036 -> 1037 click -> ..1037 페이지 크롤링 완료
# 현재 1037 -> 1038 click -> ..1038 페이지 크롤링 완료
# 현재 1038 -> 1039 click -> ..1039 페이지 크롤링 완료
# 현재 1039 -> 1040 click -> ..1040 페이지 크롤링 완료
# 현재 1040 -> 다음 click -> ..1041 페이지 크롤링 완료
# 현재 1041 -> 1042 click -> ..1042 페이지 크롤링 완료
# 현재 1042 -> 1043 click -> ..1043 페이지 크롤링 완료
# 현재 1043 -> 1044 click -> ..1044 페이지 크롤링 완료
# 현재 1044 -> 1045 click -> ..1045 페이지 크롤링 완료
# 현재 1045 -> 1046 click -> ..1046 페이지 크롤링 완료
# 현재 1046 -> 1047 click -> ..1047 페이지 크롤링 완료
# 현재 1047 -> 1048 click -> ..1048 페이지 크롤링 완료
# 현재 1048 -> 1049 click -> ..1049 페이지 크롤링 완료
# 현재 1049 -> 1050 click -> ..1050 페이지 크롤링 완료
# 현재 1050 -> 다음 click -> ..1051 페이지 크롤링 완료
# 현재 1051 -> 1052 click -> ..1052 페이지 크롤링 완료
# 현재 1052 -> 1053 click -> ..1053 페이지 크롤링 완료
# 현재 1053 -> 1054 click -> ..1054 페이지 크롤링 완료
# 현재 1054 -> 1055 click -> ..1055 페이지 크롤링 완료
# 현재 1055 -> 1056 click -> ..1056 페이지 크롤링 완료
# 현재 1056 -> 1057 click -> ..1057 페이지 크롤링 완료
# 현재 1057 -> 1058 click -> ..1058 페이지 크롤링 완료
# 현재 1058 -> 1059 click -> ..1059 페이지 크롤링 완료
# 현재 1059 -> 1060 click -> ..1060 페이지 크롤링 완료
# 현재 1060 -> 다음 click -> ..1061 페이지 크롤링 완료
# 현재 1061 -> 1062 click -> ..1062 페이지 크롤링 완료
# 현재 1062 -> 1063 click -> ..1063 페이지 크롤링 완료
# 현재 1063 -> 1064 click -> ..1064 페이지 크롤링 완료
# 현재 1064 -> 1065 click -> ..1065 페이지 크롤링 완료
# 현재 1065 -> 1066 click -> ..1066 페이지 크롤링 완료
# 현재 1066 -> 1067 click -> ..1067 페이지 크롤링 완료
# 현재 1067 -> 1068 click -> ..1068 페이지 크롤링 완료
# 현재 1068 -> 1069 click -> ..1069 페이지 크롤링 완료
# 현재 1069 -> 1070 click -> ..1070 페이지 크롤링 완료
# 현재 1070 -> 다음 click -> ..1071 페이지 크롤링 완료
# 현재 1071 -> 1072 click -> ..1072 페이지 크롤링 완료
# 현재 1072 -> 1073 click -> ..1073 페이지 크롤링 완료
# 현재 1073 -> 1074 click -> ..1074 페이지 크롤링 완료
# 현재 1074 -> 1075 click -> ..1075 페이지 크롤링 완료
# 현재 1075 -> 1076 click -> ..1076 페이지 크롤링 완료
# 현재 1076 -> 1077 click -> ..1077 페이지 크롤링 완료
# 현재 1077 -> 1078 click -> ..1078 페이지 크롤링 완료
# 현재 1078 -> 1079 click -> ..1079 페이지 크롤링 완료
# 현재 1079 -> 1080 click -> ..1080 페이지 크롤링 완료
# 현재 1080 -> 다음 click -> ..1081 페이지 크롤링 완료
# 현재 1081 -> 1082 click -> ..1082 페이지 크롤링 완료
# 현재 1082 -> 1083 click -> ..1083 페이지 크롤링 완료
# 현재 1083 -> 1084 click -> ..1084 페이지 크롤링 완료
# 현재 1084 -> 1085 click -> ..1085 페이지 크롤링 완료
# 현재 1085 -> 1086 click -> ..1086 페이지 크롤링 완료
# 현재 1086 -> 1087 click -> ..1087 페이지 크롤링 완료
# 현재 1087 -> 1088 click -> ..1088 페이지 크롤링 완료
# 현재 1088 -> 1089 click -> ..1089 페이지 크롤링 완료
# 현재 1089 -> 1090 click -> ..1090 페이지 크롤링 완료
# 현재 1090 -> 다음 click -> ..1091 페이지 크롤링 완료
# 현재 1091 -> 1092 click -> ..1092 페이지 크롤링 완료
# 현재 1092 -> 1093 click -> ..1093 페이지 크롤링 완료
# 현재 1093 -> 1094 click -> ..1094 페이지 크롤링 완료
# 현재 1094 -> 1095 click -> ..1095 페이지 크롤링 완료
# 현재 1095 -> 1096 click -> ..1096 페이지 크롤링 완료
# 현재 1096 -> 1097 click -> ..1097 페이지 크롤링 완료
# 현재 1097 -> 1098 click -> ..1098 페이지 크롤링 완료
# 현재 1098 -> 1099 click -> ..1099 페이지 크롤링 완료
# 현재 1099 -> 1100 click -> ..1100 페이지 크롤링 완료
# 현재 1100 -> 다음 click -> ..1101 페이지 크롤링 완료
# 현재 1101 -> 1102 click -> ..1102 페이지 크롤링 완료
# 현재 1102 -> 1103 click -> ..1103 페이지 크롤링 완료
# 현재 1103 -> 1104 click -> ..1104 페이지 크롤링 완료
# 현재 1104 -> 1105 click -> ..1105 페이지 크롤링 완료
# 현재 1105 -> 1106 click -> ..1106 페이지 크롤링 완료
# 현재 1106 -> 1107 click -> ..1107 페이지 크롤링 완료
# 현재 1107 -> 1108 click -> ..1108 페이지 크롤링 완료
# 현재 1108 -> 1109 click -> ..1109 페이지 크롤링 완료
# 현재 1109 -> 1110 click -> ..1110 페이지 크롤링 완료
# 현재 1110 -> 다음 click -> ..1111 페이지 크롤링 완료
# ============================================================
# 긁어온 데이터개수 : 99990
# 소요시간 : 85.55 분
# 프로그램 종료

# %%
# 세번째 셀 : 데이터 저장
# 데이터 저장 : list -> df -> csv 저장
file_name = file_name.format(date=today, first_page=1, last_page=len(result) // 90)
path = findPath(file_name)
pd.DataFrame(result, index=range(1, len(result) + 1)).to_csv(path, encoding='utf-8')

# 저장 결과 반환
if os.path.isfile(path):
    print('>>> 파일변환 완료:', datetime.today().strftime(("%Y-%m-%d %H:%M:%S")))
    print('>>> 저장위치:', path)
else: print('>>> 파일변환 실패')
# Out:
# >>> 파일변환 완료: 2021-12-03 09:12:15
# >>> 저장위치: D:\DevRoot\StockHelper\dataset\patent_20211203_1_1111.0.csv

# %%
# 네번째 셀 : 저장된 데이터 확인
file_name = file_name.format(date=today)
path = findPath(file_name)
pd.read_csv(path).style.hide_index()

# %%
patent_info = pd.read_csv(r'C:\DeepLearning_Project\StockHelper\StockHelper\dataset\patent_20211203.csv')
patent_info = patent_info.iloc[:,1:]
patent_info
# Out:
#                                                       제목  \
# 0            골프 힙턴 타이밍 연습기(Golf Hip Turn Timing Trainer)
# 1      절취 가능한 환자용 매트리스 커버(Cuttable patient mattress c...
# 2                       구이용 불판(Grill Plate For Roasting)
# 3                                       스케치북(sketchbook)
# 4      유지 보수성이 향상된 지반굴착용 교반 비트의 바이트 팁(BITE TIP OF AGI...
# ...                                                  ...
# 99985                            이동 단말기(MOBILE TERMINAL)
# 99986  생체 효과 영상을 제공하는 전자 기기의 구동 방법(METHOD OF OPERATIN...
# 99987  전기 차량을 위한 실시간 배터리 열 관리(REAL-TIME BATTERY THERM...
# 99988  내부식성이 강화된 스텐레스 연도용 배기관 및 그 제조 방법(Exhaust pipe ...
# 99989  DC-DC 컨버터 및 이를 포함하는 표시 장치(DC-DC CONVERTER AND ...
#
#                                                       내용
# 0      본 고안에 따른 골프 힙턴 타이밍 연습기는, 버클이 마련되어 허리에 착용되는 착용벨...
# 1      본 고안은 부직포층과 방수층으로 이루어지는 복수개의 시트부를 적층하여 절취 가능하도...
# 2      본 고안은 직화구이의 장점을 얻을 수 있는 동시에 그의 불편함을 개선할 수 있으며 ...
# 3      스케치북을 개시한다. 본 개시의 일 실시예에 의하면, 복수의 용지가 적층되어 구성되...
# 4      교반 날개로부터 교체가 간편한 동시에, 강도가 크게 향상되어 교체 비용을 절감시키고...
# ...                                                  ...
# 99985  사용자의 편의가 더욱 고려되어 단말기의 사용이 구현될 수 있도록 하는 이동 단말기에...
# 99986  디스플레이 장치를 포함하는 전자 기기의 구동 방법에서, 디스플레이 장치를 이용하여 ...
# 99987  방법은 복수의 배터리 셀들의 소정 배터리 셀에 대한 내부 저항을 추정하는 단계, 상...
# 99988  본 발명은 내부식성이 강화된 스텐레스 연도용 배기관을 제조하는 방법에 관한 것으로,...
# 99989  DC-DC 컨버터는 파워 스위치 및 스위칭 컨트롤러를 포함한다. 상기 파워 스위치는...
#
# [99990 rows x 2 columns]

# %%
twitter = konlpy.tag.Twitter()
nlp = twitter   # Customized Konlpy


name_pos = {
    "Noun" : "명사"
}

patent_info_str = ""

for title in patent_info.제목 :
    patent_info_str += title
    
for content in patent_info.내용 :
    patent_info_str += content
    

def sep_pos(article):
    # 기사의 어휘소 분석
    morphs = nlp.pos(article, norm=True, stem=True)
     
    pos_words = []
                     
    for pos in name_pos:  # "Noun", "Verb"  통계검색할 품사들
        
        for mal in morphs:
            # 통계집계할 단어품사만 and 단어길이가 2글자 이상만
            if pos == mal[1]:  
                pos_words.append(mal)  # 단어 추가
           
    return pos_words
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\konlpy\tag\_okt.py:16: UserWarning: "Twitter" has changed to "Okt" since KoNLPy v0.4.5.
#   warn('"Twitter" has changed to "Okt" since KoNLPy v0.4.5.')

# %%
patent_info_str
